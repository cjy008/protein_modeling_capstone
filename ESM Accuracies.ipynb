# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

import json
import pickle

# %%
with open("./ECPRED_class_labels.json") as f:
    ecpred_class_labels = json.load(f)

# %%
ecpred_class_labels
# Out:
# {'Q65GK1': '2',
#  'P16616': '2',
#  'Q1LU25': '2',
#  'Q7VRM4': '2',
#  'Q491Z6': '2',
#  'Q7WKM1': '2',
#  'Q7W785': '2',
#  'A9IKF3': '2',
#  'Q2KIN5': '2',
#  'B2S842': '2',
#  'C0RFD1': '2',
#  'B0CID9': '2',
#  'B8D8B0': '2',
#  'B4E8C4': '2',
#  'Q62LC0': '2',
#  'A4XK06': '2',
#  'A0RNT3': '2',
#  'Q8KCJ4': '2',
#  'A7FSG8': '2',
#  'P87214': '4',
#  'Q0VTD7': '1',
#  'Q89SC2': '1',
#  'Q57BW7': '1',
#  'C0REI6': '1',
#  'P63851': '1',
#  'B1JW43': '1',
#  'Q0BD83': '1',
#  'A3MI45': '1',
#  'A1V2G0': '1',
#  'B0T8D1': '1',
#  'Q1QTJ9': '1',
#  'A7MKX5': '1',
#  'A9KC01': '1',
#  'A7ZPN6': '1',
#  'B7MHT7': '1',
#  'B7NPX2': '1',
#  'B5YZY1': '1',
#  'C4ZX09': '1',
#  'Q2A3H9': '1',
#  'A0Q6H6': '1',
#  'A4IY09': '1',
#  'Q42840': '1',
#  'B5XVR1': '1',
#  'Q5ZW72': '1',
#  'Q1H4H0': '1',
#  'P36552': '1',
#  'Q7N6Z9': '1',
#  'B7V0Q9': '1',
#  'Q1MDJ5': '1',
#  'C3PM25': '1',
#  'Q1RGQ3': '1',
#  'Q9ZC86': '1',
#  'A8GU63': '1',
#  'B5F0I0': '1',
#  'B5R4G0': '1',
#  'Q5PI28': '1',
#  'B5BB50': '1',
#  'Q8Z4U8': '1',
#  'B8E3K7': '1',
#  'A5F4C4': '1',
#  'C3LPC8': '1',
#  'Q8DDD5': '1',
#  'Q8PF76': '1',
#  'Q8P3Q0': '1',
#  'Q9PHC7': '1',
#  'A7FG82': '1',
#  'B2K962': '1',
#  'A4TMK2': '1',
#  'P0C0V9': '3',
#  'P33468': '3',
#  'Q66165': '3',
#  'P31613': '3',
#  'P15776': '3',
#  'Q14EB1': '3',
#  'P30215': '3',
#  'Q8JSP9': '3',
#  'P03465': '3',
#  'P17003': '3',
#  'P07975': '3',
#  'Q67387': '3',
#  'P87691': '3',
#  'Q63ES4': '4',
#  'O04921': '4',
#  'A3N3M9': '4',
#  'A0KL51': '4',
#  'B6EHK1': '4',
#  'O67083': '4',
#  'Q7W515': '4',
#  'C0RK28': '4',
#  'A9WXE2': '4',
#  'Q0BI24': '4',
#  'Q607T4': '4',
#  'B0JRN7': '4',
#  'B1MC29': '4',
#  'A0QHT7': '4',
#  'A0PNU6': '4',
#  'B1ZSW3': '4',
#  'P57874': '4',
#  'B2SXB8': '4',
#  'Q6LTE0': '4',
#  'B2RHB4': '4',
#  'A8G3P0': '4',
#  'A9BEE9': '4',
#  'Q31C09': '4',
#  'B4F1Q1': '4',
#  'Q48MT5': '4',
#  'B7V0K1': '4',
#  'Q3K6Y7': '4',
#  'Q88PV4': '4',
#  'A5WH56': '4',
#  'B3PZU8': '4',
#  'Q98H61': '4',
#  'Q7UFZ7': '4',
#  'Q2IRD5': '4',
#  'Q6NBF3': '4',
#  'A8F0B2': '4',
#  'Q4UJN9': '4',
#  'Q68VM9': '4',
#  'Q57S74': '4',
#  'B5QU78': '4',
#  'P74132': '1',
#  'O31067': '1',
#  'Q51887': '2',
#  'Q9ZVW2': '3',
#  'Q4R3W5': '2',
#  'Q05819': '4',
#  'C7EXL6': '4',
#  'Q8U1P0': '3',
#  'Q9VR91': '2',
#  'O95714': '2',
#  'F2Z461': '2',
#  'Q9AH77': '3',
#  'Q51320': '3',
#  'D4AUH6': '3',
#  'E9DFH0': '3',
#  'P13723': '3',
#  'Q619W7': '3',
#  'Q0V8R6': '3',
#  'P06865': '3',
#  'O66129': '2',
#  'B3EWR5': '3',
#  'A7WM73': '3',
#  'P51979': '3',
#  'Q89XH1': '1',
#  'B1JWJ3': '1',
#  'Q3JPA3': '1',
#  'A4JBW6': '1',
#  'Q46UA4': '1',
#  'Q9VKJ0': '1',
#  'Q1QPR8': '1',
#  'Q5VRH4': '1',
#  'A5W8Z1': '1',
#  'Q983J4': '1',
#  'Q9X4F5': '1',
#  'Q2J1P2': '1',
#  'Q21AX5': '1',
#  'C3M930': '1',
#  'Q828S5': '1',
#  'Q4UZI9': '1',
#  'Q2NYM7': '1',
#  'Q9R098': '3',
#  'Q68CP4': '2',
#  'P51900': '2',
#  'P40235': '2',
#  'Q8QZS1': '3',
#  'Q28FR6': '3',
#  'Q7A225': '3',
#  'Q8FHF4': '2',
#  'P23874': '2',
#  'Q8NE63': '2',
#  'Q8T0S6': '2',
#  'A7HI48': '2',
#  'O67543': '2',
#  'Q75AK8': '2',
#  'B7IN98': '2',
#  'A7GMU5': '2',
#  'Q63DX3': '2',
#  'Q6HLE8': '2',
#  'Q2KTT7': '2',
#  'Q89DB4': '2',
#  'B2SCY9': '2',
#  'C0RKC9': '2',
#  'Q8FX92': '2',
#  'P59453': '2',
#  'Q9A2P5': '2',
#  'Q3B6A2': '2',
#  'A4SCX0': '2',
#  'Q7P0F7': '2',
#  'A7GDQ1': '2',
#  'A5N7Q5': '2',
#  'A9KNX6': '2',
#  'P60803': '2',
#  'Q9Z472': '2',
#  'C4LIL5': '2',
#  'Q46WL1': '2',
#  'B8HQZ8': '2',
#  'Q11TY6': '2',
#  'Q1J0A0': '2',
#  'A1VHE4': '2',
#  'A7ZNJ1': '2',
#  'B7MDH3': '2',
#  'Q8X8T4': '2',
#  'C1A4M2': '2',
#  'Q5KVC5': '2',
#  'C6E7G0': '2',
#  'A5G6I5': '2',
#  'B0R7E9': '2',
#  'A4G9J2': '2',
#  'B5XPE8': '2',
#  'B3WED6': '2',
#  'Q88UD9': '2',
#  'B1HVP7': '2',
#  'A1U458': '2',
#  'Q8TU56': '2',
#  'Q8TYD5': '2',
#  'P64346': '2',
#  'B4SCC0': '2',
#  'A8G3S5': '2',
#  'B4ET04': '2',
#  'B7UZY8': '2',
#  'B8H6U1': '2',
#  'Q3KHZ3': '2',
#  'Q87WV4': '2',
#  'Q8ZY36': '2',
#  'A1RTU8': '2',
#  'B3PRB1': '2',
#  'Q987S8': '2',
#  'C0ZZV7': '2',
#  'Q0SIE9': '2',
#  'A4FBW8': '2',
#  'B5FM40': '2',
#  'B4T9N3': '2',
#  'B5BFC1': '2',
#  'Q4A043': '2',
#  'B4STN6': '2',
#  'Q03K77': '2',
#  'Q67KH5': '2',
#  'Q4J8J2': '2',
#  'Q55503': '2',
#  'Q5JFR6': '2',
#  'B6YWA4': '2',
#  'Q7M9N0': '2',
#  'B0RSL3': '2',
#  'B2I5Y2': '2',
#  'Q4UU39': '2',
#  'Q1C9Q9': '2',
#  'A9R2K3': '2',
#  'Q0VMA1': '3',
#  'O82768': '3',
#  'C3L9P5': '3',
#  'P62346': '3',
#  'B7HKD6': '3',
#  'Q81G00': '3',
#  'Q8A7Z7': '3',
#  'A1A1J2': '3',
#  'Q2YQY7': '3',
#  'Q1BS33': '3',
#  'A0K3W0': '3',
#  'Q0BIW2': '3',
#  'Q845U5': '3',
#  'A3P025': '3',
#  'Q63Q94': '3',
#  'B8GW16': '3',
#  'Q11CK6': '3',
#  'A5CRW4': '3',
#  'C3PG92': '3',
#  'Q9RWD6': '3',
#  'Q9S5G3': '3',
#  'Q2N8I9': '3',
#  'B3E616': '3',
#  'Q7NLB5': '3',
#  'A6T374': '3',
#  'Q92E90': '3',
#  'Q8Y9G7': '3',
#  'A1U671': '3',
#  'Q0W1M3': '3',
#  'A0QZX2': '3',
#  'P9WMM8': '3',
#  'A1TAR6': '3',
#  'Q5FA47': '3',
#  'A6WX51': '3',
#  'Q13TR2': '3',
#  'B7V3G0': '3',
#  'Q4KJL6': '3',
#  'B0KM40': '3',
#  'Q87UY8': '3',
#  'A4WHB4': '3',
#  'P58853': '3',
#  'A1RTU9': '3',
#  'Q7URL1': '3',
#  'Q21U89': '3',
#  'Q2RNA8': '3',
#  'B9KPC7': '3',
#  'P10367': '3',
#  'Q8EFB6': '3',
#  'Q3Z0F9': '3',
#  'A5V9F7': '3',
#  'P64356': '3',
#  'A6UEK2': '3',
#  'Q827L8': '3',
#  'B1W4A6': '3',
#  'C3N6A4': '3',
#  'C3NGY3': '3',
#  'Q7U635': '3',
#  'C3MQI3': '3',
#  'Q31E63': '3',
#  'Q7MAQ8': '3',
#  'Q3JN03': '3',
#  'B8GZS0': '3',
#  'Q3AT43': '3',
#  'A5CRW1': '3',
#  'Q97KH7': '3',
#  'A6LT23': '3',
#  'B1ILB1': '3',
#  'A4QFF8': '3',
#  'Q1LIB3': '3',
#  'Q47AM4': '3',
#  'Q30VD6': '3',
#  'A1VHE5': '3',
#  'Q0RFX5': '3',
#  'A5G6I6': '3',
#  'A1WXS8': '3',
#  'Q9HN23': '3',
#  'Q92E89': '3',
#  'A1U670': '3',
#  'Q465C4': '3',
#  'Q1H4R1': '3',
#  'Q58825': '3',
#  'A9A817': '3',
#  'A3CX32': '3',
#  'A5UMF9': '3',
#  'P0A5B4': '3',
#  'B8ZRB5': '3',
#  'A0QX88': '3',
#  'P9WMM6': '3',
#  'A1T8W8': '3',
#  'A1KSN5': '3',
#  'Q2YAV1': '3',
#  'A5CZ72': '3',
#  'B4S4Y9': '3',
#  'Q48PJ7': '3',
#  'Q98LQ5': '3',
#  'B6IMI3': '3',
#  'Q21U90': '3',
#  'Q2IY19': '3',
#  'Q212N1': '3',
#  'B3QE24': '3',
#  'A4WRQ0': '3',
#  'Q5LST2': '3',
#  'Q2S3T1': '3',
#  'Q1GSW9': '3',
#  'A8AY23': '3',
#  'Q03K83': '3',
#  'A0LQM0': '3',
#  'Q82A89': '3',
#  'Q7N6I4': '5',
#  'Q7N8D1': '5',
#  'A1TKZ3': '5',
#  'B0VPB7': '5',
#  'A5FYE4': '5',
#  'B7GVK1': '5',
#  'Q75AP1': '5',
#  'A0RBM1': '5',
#  'B7JFZ4': '5',
#  'C1EMQ6': '5',
#  'A7GMU9': '5',
#  'Q63DW9': '5',
#  'Q9K6Z5': '5',
#  'Q65EG2': '5',
#  'A6L6Z1': '5',
#  'B3DQA4': '5',
#  'Q494D7': '5',
#  'Q7W2Y0': '5',
#  'A5E8E8': '5',
#  'Q8FY08': '5',
#  'B8D710': '5',
#  'Q1BS30': '5',
#  'Q0BIW5': '5',
#  'A3MPU5': '5',
#  'Q62GE4': '5',
#  'Q63Q91': '5',
#  'A4XL21': '5',
#  'A0RQL2': '5',
#  'A7H5V3': '5',
#  'Q5HSJ0': '5',
#  'B0T799': '5',
#  'Q3B287': '5',
#  'B9LI75': '5',
#  'Q7P0F0': '5',
#  'A6LT21': '5',
#  'A7GDQ5': '5',
#  'Q97KH9': '5',
#  'Q47XB4': '5',
#  'Q8FNZ7': '5',
#  'Q4JW54': '5',
#  'Q1LIB1': '5',
#  'B8HY50': '5',
#  'Q6BUV9': '5',
#  'Q1IWD2': '5',
#  'C6BSE3': '5',
#  'B1I557': '5',
#  'Q24QJ4': '5',
#  'B8DNB4': '5',
#  'A7ZNJ6': '5',
#  'B7L9Q1': '5',
#  'B7NQG6': '5',
#  'B1X6W1': '5',
#  'Q0TG63': '5',
#  'B7NC64': '5',
#  'Q1RA49': '5',
#  'A4WC73': '5',
#  'Q2N8I7': '5',
#  'A6GY76': '5',
#  'Q2J8L2': '5',
#  'B9M0L9': '5',
#  'A5FFX7': '5',
#  'P62354': '5',
#  'Q0AP83': '5',
#  'Q8TU55': '5',
#  'Q1H4R3': '5',
#  'A2SQR0': '5',
#  'Q8PWS2': '5',
#  'B8GJY2': '5',
#  'O26931': '5',
#  'P9WMM4': '5',
#  'Q1QRX1': '5',
#  'Q3J6Q2': '5',
#  'B4ESZ9': '5',
#  'A2BQT3': '5',
#  'Q48C80': '5',
#  'Q15RU5': '5',
#  'Q1I3G7': '5',
#  'C3K6V2': '5',
#  'Q9HU43': '5',
#  'Q87UG3': '5',
#  'A4VRW0': '5',
#  'Q4FPV8': '5',
#  'B2UEE6': '5',
#  'A9WQA3': '5',
#  'Q1MNC1': '5',
#  'B5ZV92': '5',
#  'Q7UG70': '5',
#  'Q21U92': '5',
#  'Q07UQ8': '5',
#  'Q13E39': '5',
#  'A4WUS7': '5',
#  'A3PI63': '5',
#  'B5EX43': '5',
#  'Q57MR9': '5',
#  'B5RBR6': '5',
#  'A1S6Z5': '5',
#  'Q12NS9': '5',
#  'A3QF20': '5',
#  'B8CR53': '5',
#  'B2TYF6': '5',
#  'Q32EF3': '5',
#  'A5IWA1': '5',
#  'Q5HCM3': '5',
#  'Q6GDD0': '5',
#  'Q8NUI2': '5',
#  'Q8CQ93': '5',
#  'B1W0M4': '5',
#  'O33772': '5',
#  'Q2JK82': '5',
#  'A5GKX4': '5',
#  'Q0I9E5': '5',
#  'Q0AW40': '5',
#  'Q8DMA5': '5',
#  'Q47QS4': '5',
#  'B9K9S2': '5',
#  'Q9RPQ5': '5',
#  'B0K628': '5',
#  'B1L872': '5',
#  'B5YIB4': '5',
#  'C4LFI3': '5',
#  'A1WR23': '5',
#  'B5FDA3': '5',
#  'Q7MLS2': '5',
#  'Q87C33': '5',
#  'P40545': '5',
#  'Q8ZFX9': '5',
#  'B0U3A9': '5',
#  'O28019': '2',
#  'C3L9P9': '2',
#  'B7HHG3': '2',
#  'A7GMU8': '2',
#  'Q63DX0': '2',
#  'Q9K6Z4': '2',
#  'Q5WDI0': '2',
#  'A9VLH5': '2',
#  'Q84I55': '2',
#  'Q845U9': '2',
#  'P57204': '2',
#  'P60598': '2',
#  'Q4JW55': '2',
#  'Q9TLQ8': '2',
#  'B8HUR1': '2',
#  'Q3Z7F2': '2',
#  'P61779': '2',
#  'P58237': '2',
#  'B1YL11': '2',
#  'Q5QWQ7': '2',
#  'Q02132': '2',
#  'Q6AE14': '2',
#  'P59118': '2',
#  'B8DA60': '2',
#  'A0AG17': '2',
#  'Q8TS91': '2',
#  'Q465U3': '2',
#  'Q8PVD5': '2',
#  'P59957': '2',
#  'P9WMM0': '2',
#  'Q9JVH3': '2',
#  'Q3J6Q3': '2',
#  'Q8ESS0': '2',
#  'Q3A135': '2',
#  'Q7N6I3': '2',
#  'Q8ZY40': '2',
#  'A9WQ58': '2',
#  'Q7ULP3': '2',
#  'Q5LU93': '2',
#  'O33565': '2',
#  'Q8EFB4': '2',
#  'P64364': '2',
#  'P64365': '2',
#  'Q4A047': '2',
#  'A8AY26': '2',
#  'A3CNT2': '2',
#  'Q30PY0': '2',
#  'Q67KH8': '2',
#  'Q2JVR1': '2',
#  'Q5MZ63': '2',
#  'Q8DIP5': '2',
#  'Q5JFV0': '2',
#  'Q7SIC0': '2',
#  'Q113E7': '2',
#  'Q5E635': '2',
#  'Q7M9X0': '2',
#  'Q4UU43': '2',
#  'Q9HU44': '4',
#  'A1TL06': '4',
#  'B7IBD7': '4',
#  'A3M9P1': '4',
#  'A5FYE5': '4',
#  'A4SMQ4': '4',
#  'B2UQA2': '4',
#  'Q0A5D3': '4',
#  'A6TKT6': '4',
#  'Q3MEF5': '4',
#  'A0JVK5': '4',
#  'B6EJ93': '4',
#  'C3L9P7': '4',
#  'Q81T58': '4',
#  'B7HKD4': '4',
#  'Q63DW8': '4',
#  'O34727': '4',
#  'A4YJV5': '4',
#  'Q2YQY8': '4',
#  'A9M9R9': '4',
#  'B0CJI6': '4',
#  'Q9ZHE1': '4',
#  'B1YRW1': '4',
#  'B1JUA5': '4',
#  'Q0BIW4': '4',
#  'A3MPU4': '4',
#  'Q3JN02': '4',
#  'B3PGA4': '4',
#  'B8GBF3': '4',
#  'Q3B2Q6': '4',
#  'Q3ATG0': '4',
#  'B3QSI0': '4',
#  'Q7P0E9': '4',
#  'Q9RWD7': '4',
#  'B8FP24': '4',
#  'C4XS73': '4',
#  'B8DQX6': '4',
#  'B8E2C8': '4',
#  'B7L9Q2': '4',
#  'C4ZSB4': '4',
#  'A1ACN7': '4',
#  'A5FFX6': '4',
#  'Q5KVD0': '4',
#  'P44436': '4',
#  'B4U7M4': '4',
#  'A8AAK3': '4',
#  'A6WC96': '4',
#  'B5XPE2': '4',
#  'Q1IKB2': '4',
#  'Q6AF73': '4',
#  'Q9ZGM0': '4',
#  'P59119': '4',
#  'B1HVQ1': '4',
#  'Q65RC1': '4',
#  'A6UUZ9': '4',
#  'A7I616': '4',
#  'B7KPM8': '4',
#  'Q2FPV1': '4',
#  'A2STB8': '4',
#  'A6VHY8': '4',
#  'B8IPH3': '4',
#  'A2SE09': '4',
#  'B0JY78': '4',
#  'C1ANM7': '4',
#  'B8HGA0': '4',
#  'A4VRW2': '4',
#  'A3MSG0': '4',
#  'B2UEE9': '4',
#  'B3PWI5': '4',
#  'Q13E36': '4',
#  'O33564': '4',
#  'A7NQZ5': '4',
#  'A8LX62': '4',
#  'Q2FUU0': '4',
#  'A6QKG4': '4',
#  'A8Z5H6': '4',
#  'Q31S12': '4',
#  'Q5N2A1': '4',
#  'P34041': '4',
#  'A5CVR1': '4',
#  'A7IHP3': '4',
#  'Q3M504': '2',
#  'Q73AX7': '2',
#  'Q63XM1': '2',
#  'P45358': '2',
#  'B7GZI3': '2',
#  'B9MDV4': '2',
#  'A4SMP7': '2',
#  'B6EJ89': '2',
#  'O67857': '2',
#  'Q5P791': '2',
#  'Q64RE8': '2',
#  'A8FEJ6': '2',
#  'A6L2V8': '2',
#  'A5VSV7': '2',
#  'Q9ZHE5': '2',
#  'Q84I52': '2',
#  'P56099': '2',
#  'B3ECG2': '2',
#  'A1BGB4': '2',
#  'Q7P0F4': '2',
#  'C3KVX5': '2',
#  'C1FN41': '2',
#  'B9E168': '2',
#  'Q47XB7': '2',
#  'Q6AQK2': '2',
#  'A1VEW4': '2',
#  'A7ZNJ3': '2',
#  'B7UT58': '2',
#  'B5YU77': '2',
#  'B7M400': '2',
#  'A8A1P5': '2',
#  'Q8FG51': '2',
#  'B6I848': '2',
#  'Q2N7G6': '2',
#  'A6GY79': '2',
#  'B5E9W9': '2',
#  'P61000': '2',
#  'A4IQ80': '2',
#  'A5G9G1': '2',
#  'Q0BVW4': '2',
#  'Q9HQS0': '2',
#  'Q28TL1': '2',
#  'B2GBR8': '2',
#  'Q02YW3': '2',
#  'Q04Z75': '2',
#  'B1N009': '2',
#  'Q92A83': '2',
#  'B8DC01': '2',
#  'B1HTD4': '2',
#  'A9AA96': '2',
#  'B8IRU5': '2',
#  'Q2RL44': '2',
#  'A1KJ16': '2',
#  'A3Q130': '2',
#  'A1R558': '2',
#  'Q3A7R3': '2',
#  'Q131B9': '2',
#  'A3PIA4': '2',
#  'A7NFV2': '2',
#  'Q1GET3': '2',
#  'B5FM42': '2',
#  'B4SX42': '2',
#  'B5RBR3': '2',
#  'C0Q1K1': '2',
#  'A1S6Z2': '2',
#  'Q32EF0': '2',
#  'P55683': '2',
#  'Q5JFU6': '2',
#  'Q9X0D0': '2',
#  'B1L869': '2',
#  'O82030': '2',
#  'A7MX17': '2',
#  'B5FDA0': '2',
#  'Q2P3K2': '2',
#  'Q9PBC6': '2',
#  'Q1C9R1': '2',
#  'Q1CGX0': '2',
#  'P34037': '2',
#  'Q02150': '3',
#  'Q0P4Y1': '2',
#  'Q47XB8': '1',
#  'Q3J079': '1',
#  'P73058': '1',
#  'Q6FEC8': '1',
#  'O30027': '1',
#  'Q81G06': '1',
#  'Q64RE7': '1',
#  'Q6HLE7': '1',
#  'Q8G4S9': '1',
#  'P59397': '1',
#  'Q57F99': '1',
#  'Q9ZHE6': '1',
#  'Q9RQ88': '1',
#  'Q3JMZ6': '1',
#  'Q5HSJ3': '1',
#  'Q9A5V1': '1',
#  'Q8KEY6': '1',
#  'Q8FNZ0': '1',
#  'Q4JW59': '1',
#  'Q5KVC6': '1',
#  'Q39YP7': '1',
#  'Q7NL02': '1',
#  'Q4QN74': '1',
#  'Q5V574': '1',
#  'Q8GDP4': '1',
#  'P59399': '1',
#  'Q6AE76': '1',
#  'P28736': '1',
#  'P9WNW9': '1',
#  'Q3J7H1': '1',
#  'Q8ESR8': '1',
#  'Q6D411': '1',
#  'Q4KI73': '1',
#  'Q7UX39': '1',
#  'Q2RQM7': '1',
#  'Q5PDP3': '1',
#  'P10370': '1',
#  'Q6GDC6': '1',
#  'Q21882': '3',
#  'O28314': '3',
#  'O07778': '2',
#  'A5EWS4': '2',
#  'B7MAC8': '2',
#  'Q7AAQ7': '2',
#  'B7NJR5': '2',
#  'C4ZQW9': '2',
#  'Q0TD55': '2',
#  'B1IRR4': '2',
#  'B7ND40': '2',
#  'B1LF43': '2',
#  'C5BHH2': '2',
#  'B7LQC9': '2',
#  'Q74BF6': '2',
#  'Q5FS52': '2',
#  'A5UCC3': '2',
#  'O05074': '2',
#  'Q65T41': '2',
#  'Q1H3A0': '2',
#  'Q3STQ8': '2',
#  'A1AV12': '2',
#  'B4EW46': '2',
#  'C3KDB8': '2',
#  'Q6N2R5': '2',
#  'B5F696': '2',
#  'Q57JQ9': '2',
#  'Q8XEW9': '2',
#  'A3D837': '2',
#  'B0TTF2': '2',
#  'A4Y9Z9': '2',
#  'Q0HFL0': '2',
#  'O64815': '2',
#  'Q9SZW4': '3',
#  'O64474': '3',
#  'B9DFX7': '3',
#  'O52791': '1',
#  'P17425': '2',
#  'P54872': '2',
#  'P54839': '2',
#  'Q50759': '1',
#  'P81221': '1',
#  'A8WG57': '4',
#  'Q69XJ4': '1',
#  'Q2PG53': '1',
#  'P23711': '1',
#  'E1F8H4': '1',
#  'Q81FW4': '1',
#  'P49852': '1',
#  'Q7NSD8': '1',
#  'P39662': '1',
#  'Q7ABK6': '1',
#  'Q6D245': '1',
#  'Q6LM37': '1',
#  'Q88PP0': '1',
#  'Q57LF5': '1',
#  'Q7C0F9': '1',
#  'Q9KMY3': '1',
#  'Q8ZCR0': '1',
#  'Q9FUM8': '2',
#  'P34081': '3',
#  'Q9M1W4': '2',
#  'Q6G098': '3',
#  'Q39B28': '3',
#  'Q1LC89': '3',
#  'Q0TBU8': '3',
#  'Q84EY8': '3',
#  'Q5QXD0': '3',
#  'Q7N3S7': '3',
#  'Q2K551': '3',
#  'Q98L75': '3',
#  'Q02FW7': '3',
#  'P52708': '4',
#  'P52705': '4',
#  'U3NEE3': '2',
#  'P50135': '2',
#  'Q0QLF7': '1',
#  'Q04344': '3',
#  'P11235': '3',
#  'P35740': '3',
#  'P35742': '3',
#  'Q9Q2W5': '3',
#  'P12557': '3',
#  'P12553': '3',
#  'P25465': '3',
#  'P06167': '3',
#  'P12561': '3',
#  'P28885': '3',
#  'Q783Y1': '3',
#  'Q8YVS7': '1',
#  'C1DMT5': '4',
#  'A4JPX7': '4',
#  'Q47HL8': '4',
#  'A2SI33': '4',
#  'A1UM80': '4',
#  'Q5Z2N2': '4',
#  'P51018': '4',
#  'A5V6T8': '4',
#  'Q0K3S5': '4',
#  'A3Q6M9': '4',
#  'A0PUX2': '4',
#  'Q5YV93': '4',
#  'Q13VU3': '4',
#  'P51019': '4',
#  'Q0S9W9': '4',
#  'Q9RHN1': '4',
#  'Q47B13': '4',
#  'Q0S815': '4',
#  'Q0S006': '4',
#  'C1BE28': '4',
#  'A1W2K3': '4',
#  'A0RD70': '4',
#  'A3P825': '4',
#  'B7NK03': '4',
#  'A7ZWZ9': '4',
#  'B7N8Q9': '4',
#  'B1LIN7': '4',
#  'B5XQJ4': '4',
#  'A6W1X1': '4',
#  'A0QAG9': '4',
#  'C1AHZ2': '4',
#  'A5U8K8': '4',
#  'B2T2S2': '4',
#  'Q120N9': '4',
#  'P51016': '4',
#  'B2UJF1': '4',
#  'A7NLU2': '4',
#  'Q0PHX9': '4',
#  'B9L2J0': '4',
#  'Q750A9': '2',
#  'A2QRF6': '2',
#  'P53096': '3',
#  'Q12122': '2',
#  'Q9U2M4': '1',
#  'Q9W265': '1',
#  'Q8IWW8': '1',
#  'Q6P371': '1',
#  'O60243': '2',
#  'Q8IZP7': '2',
#  'P0C9X2': '3',
#  'Q8K0D2': '3',
#  'Q5VWC8': '4',
#  'Q6DCL5': '2',
#  'Q6FQH2': '2',
#  'A6ZQG7': '2',
#  'Q9NYQ3': '1',
#  'P45387': '3',
#  'Q8RUD6': '1',
#  'P81343': '1',
#  'Q96VH4': '1',
#  'A3MME1': '3',
#  'Q3JPD1': '3',
#  'A4JBY8': '3',
#  'A3NYK1': '3',
#  'A1TWS1': '3',
#  'A1VUF3': '3',
#  'A7ZPY4': '1',
#  'B7M7P4': '1',
#  'B7N6C6': '1',
#  'Q7N4V9': '1',
#  'O23917': '2',
#  'P41938': '1',
#  'Q9WVK7': '1',
#  'B7L8Y4': '3',
#  'B7NRB5': '3',
#  'C4ZQN7': '3',
#  'B6I112': '3',
#  'Q8NXY2': '3',
#  'Q95M30': '2',
#  'P50545': '2',
#  'B8FWP2': '1',
#  'B2A0K0': '1',
#  'A9BHK9': '1',
#  'Q6LG35': '1',
#  'A9N804': '1',
#  'B4TRQ3': '1',
#  'B8EBN7': '1',
#  'B5YHX5': '1',
#  'Q944K3': '3',
#  'P56519': '3',
#  'P70288': '3',
#  'O88895': '3',
#  'Q8CDU6': '2',
#  'Q5T447': '2',
#  'Q9Y4D8': '2',
#  'Q8NG08': '3',
#  'P03214': '3',
#  'Q66647': '3',
#  'F5HEN8': '3',
#  'P52356': '3',
#  'Q2HR89': '3',
#  'Q9NRZ9': '3',
#  'A7IB61': '3',
#  'Q58524': '3',
#  'Q2IKT3': '1',
#  'A9KSC2': '1',
#  'A5FDF9': '1',
#  'Q1INI5': '1',
#  'A4WN38': '1',
#  'Q9SJX1': '1',
#  'Q6F8J3': '1',
#  'A0LRF2': '1',
#  'A3MZC2': '1',
#  'B0BTQ9': '1',
#  'A0KMZ9': '1',
#  'Q92403': '2',
#  'A6TJD3': '1',
#  'O67314': '1',
#  'Q5P7G6': '1',
#  'Q75DX7': '2',
#  'C3L6Z7': '1',
#  'A0RJ83': '1',
#  'Q817Q8': '1',
#  'Q9K8F8': '1',
#  'Q65GJ9': '1',
#  'A8FFV4': '1',
#  'A7Z7A7': '1',
#  'C0ZAG9': '1',
#  'A2RYL1': '1',
#  'A3NZS3': '1',
#  'Q2SUG3': '1',
#  'B9KGB2': '1',
#  'Q6FXE3': '2',
#  'P07997': '2',
#  'A4SFJ7': '1',
#  'B7V0L2': '1',
#  'Q1IEX2': '1',
#  'A5VYG4': '1',
#  'Q88PW6': '1',
#  'Q4ZXW8': '1',
#  'Q1QED0': '1',
#  'Q8ZYV6': '1',
#  'P08080': '2',
#  'P18079': '2',
#  'C1AZ44': '1',
#  'Q04512': '2',
#  'Q68VS3': '2',
#  'A1AX01': '1',
#  'A6WSF1': '1',
#  'A3QH31': '1',
#  'A4Y3J7': '1',
#  'Q0HFC7': '1',
#  'Q83RP1': '1',
#  'Q2NRS3': '1',
#  'A9FDP5': '1',
#  'Q2FXQ9': '1',
#  'Q2YTB7': '1',
#  'A6QHK6': '1',
#  'Q6GG33': '1',
#  'B9DND0': '1',
#  'Q8CNY6': '1',
#  'B2FQ15': '1',
#  'Q4JAM9': '1',
#  'C3MZS1': '1',
#  'C3MYE2': '1',
#  'A6Q7Y8': '1',
#  'Q976H4': '1',
#  'Q31QY3': '1',
#  'B5YJZ3': '1',
#  'Q83H91': '1',
#  'B7JQ57': '2',
#  'C1ETR0': '2',
#  ...}

# %%
a = np.load("./test_ecpred_from_esm.npz", allow_pickle=True)

# %%
a_data = {}

for data in a:
    a_data[data] = a[data]

# %% [markdown]
# #### Verify the test data is not part of the train data

# %%
c = np.load("./all_ecpred_from_esm.npz", allow_pickle=True)

# %%
c['B7M2G1']
# Out:
# numpy.ndarray

# %%
c_data = {}

for data in c:
    c_data[data] = c[data]

# %%
intersection = set(list(a_data.keys())) & set(list(c_data.keys()))

# %%
intersection
# Out:
# set()

# %%
test_data = pd.DataFrame(a_data.items(), columns=['identifier', 'embeddings'])

# %%
test_data['classes'] = test_data['identifier'].map(ecpred_class_labels)

# %%
test_data['enzyme_non_enzyme'] = "1"

# %%
test_data
# Out:
#     identifier                                         embeddings classes  \
# 0       Q8HVP5  [0.033683684, 0.049727384, -0.016321301, 0.039...       1
# 1       Q8HVS5  [0.033807687, 0.04896432, -0.015200496, 0.0365...       1
# 2       P0C386  [0.018022297, 0.02248324, -0.06277644, 0.06475...       1
# 3       Q8HVN4  [0.033129636, 0.049638327, -0.010831154, 0.034...       1
# 4       Q0B4Z6  [0.11726774, 0.2692161, -0.05544941, 0.0621133...       2
# ..         ...                                                ...     ...
# 355     Q8Z080  [0.049787696, 0.09494831, -0.014217152, 0.0826...       2
# 356     Q3V7K1  [0.04744051, 0.07840378, -0.02636614, 0.056081...       2
# 357     Q8Z4K6  [0.04725945, 0.07858272, -0.023864051, 0.05558...       2
# 358     Q3BZR9  [0.0028418622, 0.08328892, 0.015781334, 0.0413...       2
# 359     Q7MAP8  [0.06580827, 0.12938114, -0.02438996, 0.114384...       2
#
#     enzyme_non_enzyme
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ..                ...
# 355                 1
# 356                 1
# 357                 1
# 358                 1
# 359                 1
#
# [360 rows x 4 columns]

# %%
b = np.load("./all_deeppre_from_esm.npz", allow_pickle=True)

# %%
b_data = {}

for data in b:
    b_data[data] = b[data]

# %%
b['ENZY12425']
# Out:
# array([ 0.12746994,  0.27281544,  0.06692323, ...,  0.03192677,
#        -0.12083121,  0.10100751], dtype=float32)

# %%
with open("./1024_NonEnzymes_Enzymes_labels.json") as f:
    nonenzyme_enzyme_labels = json.load(f)

# %%
ne_e_test_data = pd.DataFrame(b_data.items(), columns=['identifier', 'embeddings'])

# %%
ne_e_test_data['enzyme_nonenzyme'] = ne_e_test_data['identifier'].map(nonenzyme_enzyme_labels)

# %%
ne_e_test_data
# Out:
#       identifier                                         embeddings  \
# 0      ENZY12425  [0.12746994, 0.27281544, 0.06692323, 0.1448938...
# 1       ENZY3790  [0.12582903, 0.11324516, 0.11739114, 0.1498377...
# 2       ENZY5288  [0.13101612, 0.30415857, 0.17695493, -0.022740...
# 3      ENZY13326  [0.026205149, 0.21668276, 0.05241565, 7.565544...
# 4       ENZY2952  [0.07479797, -0.0067801224, 0.077018805, 0.008...
# ...          ...                                                ...
# 26330  ENZY11657  [-0.02991949, 0.19900143, 0.07266715, 0.152193...
# 26331   ENZY1891  [0.1251773, 0.10361989, 0.052353505, -0.006737...
# 26332  ENZY21537  [-0.070309326, 0.012636613, -0.058369204, 0.15...
# 26333  ENZY10759  [0.12393214, 0.13972586, 0.039379448, 0.215272...
# 26334  ENZY20455  [0.07451792, 0.0815477, -0.00480333, 0.1273093...
#
#       enzyme_nonenzyme
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 26330                1
# 26331                1
# 26332                1
# 26333                1
# 26334                1
#
# [26335 rows x 3 columns]

# %%
x_test = list(test_data['embeddings'])
y_test_class = list(test_data['classes'])
y_test_binary = list(test_data['enzyme_non_enzyme'])

# %%
x_test
# Out:
# [array([ 0.03368368,  0.04972738, -0.0163213 , ..., -0.13593875,
#         -0.03433039, -0.06656401], dtype=float32),
#  array([ 0.03380769,  0.04896432, -0.0152005 , ..., -0.13321853,
#         -0.03336693, -0.0679692 ], dtype=float32),
#  array([ 0.0180223 ,  0.02248324, -0.06277644, ..., -0.1031374 ,
#         -0.01176274, -0.0366175 ], dtype=float32),
#  array([ 0.03312964,  0.04963833, -0.01083115, ..., -0.12932996,
#         -0.03356467, -0.07291717], dtype=float32),
#  array([ 0.11726774,  0.2692161 , -0.05544941, ..., -0.02116028,
#         -0.02082298,  0.07637652], dtype=float32),
#  array([ 0.0784464 ,  0.28879067, -0.04174797, ..., -0.08063894,
#         -0.05886092,  0.06509774], dtype=float32),
#  array([ 0.14412081,  0.33220333, -0.1289441 , ..., -0.05485492,
#         -0.10075965, -0.00375912], dtype=float32),
#  array([ 0.13952522,  0.3299176 , -0.1396554 , ..., -0.05689486,
#         -0.10297772,  0.0057671 ], dtype=float32),
#  array([ 0.1049448 ,  0.24859513, -0.11302238, ..., -0.06344181,
#         -0.09363758,  0.07873002], dtype=float32),
#  array([ 0.1025773 ,  0.24132214, -0.12399334, ..., -0.07347886,
#         -0.05821407,  0.04341012], dtype=float32),
#  array([ 0.0771764 ,  0.23958735, -0.06596723, ..., -0.03286014,
#         -0.03156637,  0.05896013], dtype=float32),
#  array([ 0.08374044,  0.2562057 , -0.05364031, ..., -0.03760761,
#         -0.02475263,  0.0601224 ], dtype=float32),
#  array([ 0.07206155,  0.2688667 , -0.05073581, ..., -0.04921872,
#         -0.04894559,  0.04801097], dtype=float32),
#  array([ 0.07920971,  0.25913125, -0.05087271, ..., -0.04392044,
#         -0.04557575,  0.04908663], dtype=float32),
#  array([ 0.07736191,  0.24297722, -0.08894572, ..., -0.04300055,
#         -0.03964947,  0.0455258 ], dtype=float32),
#  array([ 0.07206155,  0.2688667 , -0.05073581, ..., -0.04921872,
#         -0.04894559,  0.04801097], dtype=float32),
#  array([ 0.09107013,  0.24476099, -0.11368623, ..., -0.08016953,
#         -0.07029317,  0.032463  ], dtype=float32),
#  array([ 0.08094303,  0.24335182, -0.06383172, ..., -0.06350735,
#         -0.05873541,  0.04713832], dtype=float32),
#  array([ 0.07094275,  0.27875262, -0.08487491, ..., -0.0567372 ,
#         -0.05512613,  0.03391929], dtype=float32),
#  array([ 0.07656121,  0.29743227, -0.05375709, ..., -0.0494124 ,
#         -0.0455856 ,  0.03213653], dtype=float32),
#  array([ 0.11146949,  0.22846755, -0.17083125, ..., -0.08137433,
#         -0.06065512,  0.06265904], dtype=float32),
#  array([ 0.0944217 ,  0.25048012, -0.10987367, ..., -0.08654149,
#         -0.0871986 ,  0.04135917], dtype=float32),
#  array([ 0.10877661,  0.22327106, -0.1597988 , ..., -0.08934578,
#         -0.07544787,  0.05110982], dtype=float32),
#  array([ 0.09527647,  0.24370538, -0.1758311 , ..., -0.09518683,
#         -0.07323877,  0.03994653], dtype=float32),
#  array([ 0.0964447 ,  0.23962834, -0.1423881 , ..., -0.09182082,
#         -0.06990884,  0.0409308 ], dtype=float32),
#  array([ 0.10789087,  0.2345334 , -0.15900415, ..., -0.09102647,
#         -0.08045428,  0.05380246], dtype=float32),
#  array([ 0.1020392 ,  0.23902948, -0.12284831, ..., -0.08928061,
#         -0.07992609,  0.05103705], dtype=float32),
#  array([ 0.11241814,  0.24374141, -0.1311824 , ..., -0.07931223,
#         -0.0804003 ,  0.0513666 ], dtype=float32),
#  array([ 0.11121643,  0.13222831,  0.02739696, ..., -0.06330087,
#          0.07982604,  0.08779751], dtype=float32),
#  array([ 0.1317329 ,  0.2330006 , -0.15531105, ..., -0.07549449,
#         -0.06102678,  0.02963796], dtype=float32),
#  array([ 0.08182275,  0.28418735, -0.11231813, ..., -0.05506282,
#         -0.02363724,  0.01149371], dtype=float32),
#  array([ 0.07174677,  0.21402119, -0.06131295, ..., -0.07843591,
#         -0.05745111,  0.14540428], dtype=float32),
#  array([ 0.07793098,  0.08854838, -0.01048274, ..., -0.0819478 ,
#          0.00543139,  0.06898719], dtype=float32),
#  array([ 0.15539527,  0.1239896 , -0.05735413, ..., -0.07969107,
#         -0.02733588, -0.00956161], dtype=float32),
#  array([ 0.13259658,  0.12400726,  0.02224522, ..., -0.04063531,
#          0.01648166,  0.02728823], dtype=float32),
#  array([ 0.13259658,  0.12400726,  0.02224522, ..., -0.04063531,
#          0.01648166,  0.02728823], dtype=float32),
#  array([ 0.09590914,  0.09914313,  0.01076624, ..., -0.06959217,
#          0.02325585,  0.05380738], dtype=float32),
#  array([ 0.13869786,  0.10307365,  0.00388335, ..., -0.0533859 ,
#          0.02910697,  0.0744421 ], dtype=float32),
#  array([ 0.1262272 ,  0.12013382, -0.03851158, ..., -0.06367503,
#         -0.01330547,  0.00101852], dtype=float32),
#  array([ 0.08201276,  0.12313279,  0.07785762, ..., -0.0834863 ,
#          0.02426717,  0.08634205], dtype=float32),
#  array([ 0.1290527 ,  0.13273829,  0.04033684, ..., -0.05599857,
#         -0.01735518,  0.04065168], dtype=float32),
#  array([ 0.11112116,  0.10221761,  0.02992606, ..., -0.084728  ,
#          0.0734137 ,  0.01393798], dtype=float32),
#  array([ 0.10309947,  0.13297407,  0.05771882, ..., -0.07319714,
#          0.05148985,  0.08999699], dtype=float32),
#  array([ 0.10036091,  0.12494117,  0.07514211, ..., -0.04897269,
#          0.06925626,  0.09054655], dtype=float32),
#  array([-0.01455604,  0.20634896,  0.09248584, ..., -0.03167255,
#         -0.14335893,  0.17002816], dtype=float32),
#  array([-0.07356308,  0.22698815,  0.18741822, ..., -0.00886203,
#         -0.21124597, -0.02383118], dtype=float32),
#  array([-0.03920865,  0.33591905,  0.12809609, ..., -0.06677206,
#         -0.16353966, -0.06141151], dtype=float32),
#  array([ 0.03094323,  0.1351992 , -0.09789604, ..., -0.01330584,
#          0.00046263,  0.25800392], dtype=float32),
#  array([ 0.00454704,  0.27759755,  0.00370396, ..., -0.13446386,
#         -0.11617849, -0.10101622], dtype=float32),
#  array([ 0.05230574,  0.08839255,  0.09397069, ..., -0.02039124,
#         -0.10357607,  0.05886966], dtype=float32),
#  array([ 0.09030764,  0.11507257,  0.01029915, ..., -0.03669058,
#         -0.09510589,  0.06847615], dtype=float32),
#  array([ 0.08468368,  0.20256597, -0.08719846, ..., -0.11029254,
#         -0.1290163 ,  0.13746607], dtype=float32),
#  array([ 0.05374585,  0.27557498, -0.12051522, ...,  0.04000755,
#         -0.07166174,  0.03759242], dtype=float32),
#  array([-0.01581333,  0.33370167, -0.01986497, ..., -0.24209887,
#         -0.14690411,  0.20398122], dtype=float32),
#  array([-0.01212823,  0.2890754 ,  0.05379621, ...,  0.01147657,
#         -0.17178632,  0.09921156], dtype=float32),
#  array([ 0.03806401,  0.220818  ,  0.10403971, ..., -0.00528908,
#         -0.17098583,  0.20075095], dtype=float32),
#  array([ 0.02940306,  0.36020207,  0.05112263, ..., -0.13892674,
#         -0.26056695, -0.12628412], dtype=float32),
#  array([-0.07171165,  0.29989704,  0.06669226, ..., -0.04364925,
#         -0.21408288,  0.01409412], dtype=float32),
#  array([-0.02605636,  0.30748376,  0.09111988, ...,  0.02137624,
#         -0.3100296 ,  0.07777391], dtype=float32),
#  array([ 0.06659738,  0.11042758, -0.02712173, ..., -0.06178031,
#          0.04730164,  0.31900704], dtype=float32),
#  array([ 0.08691707,  0.24321122, -0.09593672, ..., -0.07164925,
#          0.02203484,  0.02692268], dtype=float32),
#  array([ 0.03948443,  0.20910355,  0.07658598, ..., -0.16180627,
#         -0.05890846,  0.03124649], dtype=float32),
#  array([ 0.03948443,  0.20910355,  0.07658598, ..., -0.16180627,
#         -0.05890846,  0.03124649], dtype=float32),
#  array([ 0.08520445, -0.02221663, -0.01838318, ...,  0.00095022,
#          0.03953202,  0.21080825], dtype=float32),
#  array([ 0.00716544,  0.17133619,  0.04743683, ..., -0.09977073,
#          0.0431362 ,  0.15923703], dtype=float32),
#  array([ 0.05113479,  0.23580341,  0.07844272, ..., -0.1393507 ,
#         -0.05584965,  0.03213134], dtype=float32),
#  array([ 0.03605683,  0.1844805 ,  0.09138197, ..., -0.17220077,
#         -0.02978694,  0.05435414], dtype=float32),
#  array([ 0.04279006,  0.19638823,  0.04432472, ..., -0.15676515,
#         -0.01684701, -0.00827924], dtype=float32),
#  array([ 0.07640528,  0.1144899 , -0.11527994, ..., -0.02826495,
#         -0.08001212,  0.07918891], dtype=float32),
#  array([ 0.07881362,  0.02109904, -0.09848209, ..., -0.0830697 ,
#         -0.10247255,  0.12087631], dtype=float32),
#  array([ 0.06561609,  0.0437811 , -0.1473156 , ..., -0.05375447,
#         -0.09748163,  0.09151755], dtype=float32),
#  array([ 0.00823844,  0.01417184, -0.06181902, ..., -0.03913238,
#         -0.16897298,  0.09598232], dtype=float32),
#  array([ 0.03939113,  0.09827044,  0.01934621, ...,  0.02976269,
#         -0.00599475,  0.08856299], dtype=float32),
#  array([-0.0108518 ,  0.1285867 ,  0.12020703, ..., -0.17176828,
#         -0.02469681,  0.03303643], dtype=float32),
#  array([-0.01238362, -0.00306057, -0.08331432, ..., -0.04143354,
#         -0.14684738,  0.07778203], dtype=float32),
#  array([ 0.11421366,  0.14404663, -0.03561906, ..., -0.14001802,
#         -0.12746799,  0.14343134], dtype=float32),
#  array([ 0.01166641,  0.17711009,  0.03395253, ..., -0.05195533,
#         -0.09244783,  0.14554636], dtype=float32),
#  array([ 0.07261734,  0.07029338, -0.1025172 , ..., -0.02025763,
#         -0.12983127,  0.14282529], dtype=float32),
#  array([ 0.0600915 ,  0.07636128,  0.03654721, ...,  0.04372321,
#         -0.05997121,  0.20790058], dtype=float32),
#  array([ 0.06996208,  0.06863493, -0.09958281, ..., -0.02043128,
#         -0.117416  ,  0.14341514], dtype=float32),
#  array([ 0.04979451,  0.08534545, -0.02425791, ..., -0.02739209,
#         -0.13121367,  0.17820764], dtype=float32),
#  array([ 0.07000276,  0.06951734, -0.0988618 , ..., -0.01884112,
#         -0.11662054,  0.14431706], dtype=float32),
#  array([ 0.04119296,  0.06093984, -0.02248438, ..., -0.01856156,
#         -0.11839139,  0.15150832], dtype=float32),
#  array([ 0.05954222,  0.07756679,  0.03623637, ...,  0.04348171,
#         -0.0574227 ,  0.20868321], dtype=float32),
#  array([ 0.06185675,  0.0449217 ,  0.07380209, ...,  0.06120058,
#         -0.09446244,  0.18429951], dtype=float32),
#  array([ 0.04674081,  0.0528375 ,  0.01495855, ..., -0.01174795,
#         -0.11409354,  0.1762896 ], dtype=float32),
#  array([ 0.05562962,  0.06904423,  0.01459906, ...,  0.01178414,
#         -0.08795199,  0.16466317], dtype=float32),
#  array([ 0.04715053,  0.0869395 , -0.01721031, ..., -0.03232845,
#         -0.12678058,  0.16590743], dtype=float32),
#  array([ 0.06466319,  0.0439655 ,  0.08889061, ...,  0.06500085,
#         -0.09878614,  0.18785928], dtype=float32),
#  array([ 0.0586572 ,  0.05772476,  0.06160456, ...,  0.02152026,
#         -0.10182515,  0.1734529 ], dtype=float32),
#  array([ 0.06007195,  0.06754234,  0.06322563, ...,  0.01958048,
#         -0.10269941,  0.17611896], dtype=float32),
#  array([ 0.05539151,  0.06205967,  0.05617467, ...,  0.04908093,
#         -0.06883073,  0.18024069], dtype=float32),
#  array([ 0.04082599,  0.06142663, -0.00661859, ..., -0.03123293,
#         -0.12040386,  0.1505273 ], dtype=float32),
#  array([ 0.0819952 ,  0.10941032, -0.11757169, ..., -0.0103869 ,
#         -0.11945289,  0.16030344], dtype=float32),
#  array([ 0.0819952 ,  0.10941032, -0.11757169, ..., -0.0103869 ,
#         -0.11945289,  0.16030344], dtype=float32),
#  array([ 0.0799348 ,  0.09472246, -0.1486685 , ..., -0.02502465,
#         -0.13469909,  0.17019832], dtype=float32),
#  array([ 0.08127428,  0.11026086, -0.11692379, ..., -0.01108712,
#         -0.1207142 ,  0.16090094], dtype=float32),
#  array([ 0.0819952 ,  0.10941032, -0.11757169, ..., -0.0103869 ,
#         -0.11945289,  0.16030344], dtype=float32),
#  array([ 0.0819952 ,  0.10941032, -0.11757169, ..., -0.0103869 ,
#         -0.11945289,  0.16030344], dtype=float32),
#  array([ 0.0819952 ,  0.10941032, -0.11757169, ..., -0.0103869 ,
#         -0.11945289,  0.16030344], dtype=float32),
#  array([ 0.11435021,  0.09416305, -0.00577177, ...,  0.02492326,
#         -0.04108641,  0.11836962], dtype=float32),
#  array([ 0.11347831,  0.10154981, -0.02062885, ...,  0.01750753,
#         -0.02911945,  0.20518291], dtype=float32),
#  array([ 0.13376984,  0.04696181,  0.00904862, ...,  0.03472054,
#         -0.04415178,  0.12320442], dtype=float32),
#  array([ 0.11735529,  0.06861191,  0.02464657, ..., -0.00087482,
#         -0.05295813,  0.19054742], dtype=float32),
#  array([0.10877687, 0.08964916, 0.00957521, ..., 0.00918298, 0.00419016,
#         0.21497123], dtype=float32),
#  array([-0.01953856,  0.08327288, -0.08025812, ..., -0.06012994,
#         -0.08492735,  0.13684022], dtype=float32),
#  array([ 0.09887759,  0.04950114,  0.01947099, ...,  0.00534528,
#         -0.06120686,  0.11176279], dtype=float32),
#  array([ 0.10740866,  0.08369651, -0.0260223 , ..., -0.02115471,
#         -0.05102655,  0.14889833], dtype=float32),
#  array([ 0.06156669,  0.16555752, -0.03781484, ..., -0.17596294,
#         -0.16084091,  0.0866387 ], dtype=float32),
#  array([ 0.06887683,  0.18257578, -0.0238668 , ..., -0.16690235,
#         -0.09370986,  0.09791921], dtype=float32),
#  array([ 0.10744442,  0.24359682, -0.00725809, ..., -0.12680545,
#         -0.09834699,  0.12208669], dtype=float32),
#  array([ 0.12049418,  0.24342053, -0.17956558, ..., -0.17362395,
#         -0.18439594,  0.11359751], dtype=float32),
#  array([ 0.0510008 ,  0.19547187, -0.1212722 , ..., -0.22181985,
#         -0.11374764,  0.05476781], dtype=float32),
#  array([-0.05509049,  0.11919896, -0.08384936, ..., -0.08012898,
#         -0.1321705 ,  0.04653849], dtype=float32),
#  array([ 0.11901379,  0.17978653, -0.0603114 , ..., -0.17667882,
#         -0.20241259,  0.06763595], dtype=float32),
#  array([ 0.05589077,  0.24198905, -0.11736943, ..., -0.18401356,
#         -0.15907042,  0.09628721], dtype=float32),
#  array([-0.07188136,  0.2802289 ,  0.11256731, ...,  0.0511962 ,
#         -0.05642455,  0.04495496], dtype=float32),
#  array([-0.07778641,  0.29185927,  0.1085947 , ...,  0.0625258 ,
#         -0.06095038,  0.04523483], dtype=float32),
#  array([-0.06737494,  0.27518997,  0.11747208, ...,  0.05385293,
#         -0.03895074,  0.06454253], dtype=float32),
#  array([-0.0231318 ,  0.25521648, -0.09825063, ..., -0.16180035,
#          0.02836657, -0.04805667], dtype=float32),
#  array([-0.00856524,  0.06023913,  0.10516671, ..., -0.14845736,
#         -0.23117445, -0.00369405], dtype=float32),
#  array([ 0.00370496,  0.23672816, -0.02476611, ...,  0.01625675,
#         -0.08431438,  0.19644377], dtype=float32),
#  array([ 0.05269396,  0.07293942,  0.14046285, ..., -0.05039698,
#         -0.2375737 ,  0.03481996], dtype=float32),
#  array([-0.03904151,  0.14057028,  0.15676871, ..., -0.01830089,
#         -0.11650833,  0.04647556], dtype=float32),
#  array([-0.18876755,  0.28026536,  0.04384043, ..., -0.06883276,
#         -0.11040483, -0.12179456], dtype=float32),
#  array([ 0.04296833,  0.2717715 , -0.10099944, ..., -0.04315366,
#         -0.00162682,  0.2179076 ], dtype=float32),
#  array([-0.16196398,  0.34128594,  0.10064285, ..., -0.01614325,
#         -0.12836376, -0.07732936], dtype=float32),
#  array([-0.19200371,  0.32183024, -0.00397546, ..., -0.0144738 ,
#         -0.12636252, -0.03335316], dtype=float32),
#  array([ 0.05305421,  0.1871507 , -0.21850112, ..., -0.03618734,
#          0.01171938, -0.07473566], dtype=float32),
#  array([ 0.08754361,  0.16108312, -0.15983838, ...,  0.02254874,
#          0.03535964, -0.04581825], dtype=float32),
#  array([ 0.06123617,  0.1629551 , -0.2272243 , ..., -0.03603501,
#          0.0160732 , -0.0930695 ], dtype=float32),
#  array([ 0.05892318,  0.19158237, -0.15842706, ..., -0.02572018,
#          0.00577628, -0.04422325], dtype=float32),
#  array([ 0.05156019,  0.13951768, -0.11758442, ...,  0.03398763,
#          0.02094557, -0.07087743], dtype=float32),
#  array([ 0.08909015,  0.16844027, -0.12127811, ...,  0.02416958,
#          0.01310281, -0.06430829], dtype=float32),
#  array([ 0.07176246,  0.16185333, -0.16983269, ..., -0.0183416 ,
#          0.01077683, -0.04845261], dtype=float32),
#  array([ 0.05280537,  0.17416306, -0.08489273, ...,  0.04122791,
#          0.02032718, -0.04615129], dtype=float32),
#  array([-0.03110201,  0.08888746, -0.0116139 , ..., -0.07385504,
#         -0.09366079,  0.15874967], dtype=float32),
#  array([-0.04303615,  0.09494262, -0.03038232, ..., -0.0844446 ,
#         -0.06477635,  0.16336797], dtype=float32),
#  array([-0.01560399,  0.07888325, -0.04717677, ..., -0.11315547,
#         -0.1052101 ,  0.14019516], dtype=float32),
#  array([-0.03817565,  0.09437606,  0.01032945, ..., -0.08468474,
#         -0.03870896,  0.15985548], dtype=float32),
#  array([-0.02030818,  0.11196694, -0.0173326 , ..., -0.0915901 ,
#         -0.07311472,  0.16848387], dtype=float32),
#  array([-0.0141732 ,  0.07771509, -0.04333755, ..., -0.11382621,
#         -0.10799744,  0.14148234], dtype=float32),
#  array([-0.0227485 ,  0.07814977, -0.03005   , ..., -0.11238359,
#         -0.09403843,  0.13529731], dtype=float32),
#  array([-0.0177634 ,  0.11214276, -0.08648264, ..., -0.10150688,
#         -0.10383008,  0.13923705], dtype=float32),
#  array([ 0.01385217,  0.1246821 ,  0.03422305, ..., -0.01782294,
#         -0.08986045,  0.137264  ], dtype=float32),
#  array([ 0.01569843,  0.08560103,  0.08177885, ..., -0.04696353,
#         -0.10065301,  0.14995508], dtype=float32),
#  array([ 0.01662268,  0.08691071,  0.07565447, ..., -0.04553755,
#         -0.09949806,  0.14893322], dtype=float32),
#  array([ 0.00392037,  0.06839857,  0.13494992, ..., -0.00293628,
#         -0.06641373,  0.142705  ], dtype=float32),
#  array([-0.00561766,  0.10389921,  0.06414825, ..., -0.04565933,
#         -0.09510493,  0.13780285], dtype=float32),
#  array([-0.00024804,  0.10162961,  0.0537152 , ..., -0.04521343,
#         -0.08850927,  0.13556327], dtype=float32),
#  array([ 0.03607497,  0.15264645, -0.06764743, ..., -0.08151151,
#         -0.10044656,  0.14150213], dtype=float32),
#  array([-0.00139128,  0.12542559,  0.0439423 , ..., -0.02597375,
#         -0.08684565,  0.11504008], dtype=float32),
#  array([ 0.0238823 ,  0.14956526, -0.19197178, ..., -0.01350576,
#         -0.14941305,  0.02781351], dtype=float32),
#  array([ 0.00505776,  0.0458731 , -0.02939787, ...,  0.04574666,
#         -0.10784587,  0.08321328], dtype=float32),
#  array([ 0.02096844,  0.04823584, -0.07158244, ...,  0.06255751,
#         -0.10492188,  0.097522  ], dtype=float32),
#  array([-0.00433466,  0.07453482, -0.06360085, ...,  0.0358434 ,
#         -0.11184543,  0.08624344], dtype=float32),
#  array([ 0.07514736,  0.14129856, -0.11428375, ..., -0.01260277,
#         -0.14602315,  0.01789434], dtype=float32),
#  array([ 0.0454395 ,  0.11372469, -0.06401129, ...,  0.04349604,
#         -0.11959192,  0.08907232], dtype=float32),
#  array([ 0.02579596,  0.1141687 , -0.13503926, ..., -0.00194872,
#         -0.09413646, -0.02168169], dtype=float32),
#  array([ 0.02422898,  0.13919275, -0.20594658, ..., -0.02287844,
#         -0.10910438,  0.00539982], dtype=float32),
#  array([ 0.01604218,  0.05117488, -0.06971093, ...,  0.05036133,
#         -0.16742262,  0.09784764], dtype=float32),
#  array([ 0.03730289,  0.13272192, -0.07288674, ...,  0.04498193,
#         -0.11235001,  0.04907777], dtype=float32),
#  array([ 0.08551591,  0.13914147, -0.11155505, ..., -0.02355941,
#         -0.09986037,  0.09689081], dtype=float32),
#  array([ 0.04578279,  0.04385677, -0.07646549, ...,  0.05180991,
#         -0.14918466,  0.10768659], dtype=float32),
#  array([ 0.04090189,  0.09413404, -0.12788759, ...,  0.04295301,
#         -0.13559406,  0.10366129], dtype=float32),
#  array([ 0.06256084,  0.07842874, -0.05180709, ...,  0.05177796,
#         -0.11820327,  0.09842993], dtype=float32),
#  array([ 0.04968809,  0.12966123, -0.0753924 , ...,  0.03579434,
#         -0.13502751,  0.08630084], dtype=float32),
#  array([ 0.03105192,  0.09972408, -0.13012955, ...,  0.03224815,
#         -0.10827759,  0.10037496], dtype=float32),
#  array([ 0.043327  ,  0.10474317, -0.0498358 , ..., -0.14227352,
#          0.09515162, -0.0279422 ], dtype=float32),
#  array([ 0.0507534 ,  0.10384652,  0.03041661, ..., -0.08326134,
#          0.07324392,  0.02321676], dtype=float32),
#  array([ 0.06192674,  0.09929173,  0.02532526, ..., -0.07882026,
#          0.12204088,  0.02074969], dtype=float32),
#  array([ 0.05863071,  0.11121717,  0.01372578, ..., -0.07196841,
#          0.11486906,  0.0390098 ], dtype=float32),
#  array([ 0.04319516,  0.31665918, -0.04620003, ..., -0.11783075,
#         -0.05421388, -0.02410417], dtype=float32),
#  array([ 0.02865838,  0.2104678 ,  0.01374069, ..., -0.09914539,
#         -0.02637877,  0.04820688], dtype=float32),
#  array([ 0.10135993,  0.10293558,  0.00125683, ..., -0.01920223,
#         -0.02859895, -0.02333662], dtype=float32),
#  array([ 0.09579706,  0.30733496, -0.16237678, ..., -0.15732454,
#         -0.0615208 , -0.01015915], dtype=float32),
#  array([ 0.09668439,  0.12516445, -0.00857974, ..., -0.03307089,
#         -0.04431129, -0.04045589], dtype=float32),
#  array([ 0.09668439,  0.12516445, -0.00857974, ..., -0.03307089,
#         -0.04431129, -0.04045589], dtype=float32),
#  array([ 0.09668439,  0.12516445, -0.00857974, ..., -0.03307089,
#         -0.04431129, -0.04045589], dtype=float32),
#  array([ 0.09668439,  0.12516445, -0.00857974, ..., -0.03307089,
#         -0.04431129, -0.04045589], dtype=float32),
#  array([ 0.09014948,  0.06796302, -0.00017981, ...,  0.10881525,
#          0.09106277,  0.1467503 ], dtype=float32),
#  array([ 0.00145899,  0.29507685, -0.05938311, ...,  0.1336754 ,
#         -0.02672195, -0.00515812], dtype=float32),
#  array([-0.02484016,  0.17127585, -0.10406872, ..., -0.04155668,
#          0.07927962,  0.08568176], dtype=float32),
#  array([-0.00195753,  0.17730421, -0.05200463, ..., -0.05253538,
#          0.0305886 ,  0.044593  ], dtype=float32),
#  array([-0.03216699,  0.18392144, -0.01494671, ..., -0.06240486,
#         -0.02090663,  0.04569825], dtype=float32),
#  array([-0.03615274,  0.15502813, -0.04986395, ..., -0.05653571,
#          0.01134471,  0.10365971], dtype=float32),
#  array([-0.04145227,  0.16489752, -0.03387495, ..., -0.02331169,
#          0.03575414,  0.07320145], dtype=float32),
#  array([ 0.00161327,  0.20830068, -0.0414888 , ..., -0.05198217,
#          0.03371762,  0.04297755], dtype=float32),
#  array([-0.00289953,  0.18517037, -0.10615123, ..., -0.06757752,
#          0.03152436,  0.06371329], dtype=float32),
#  array([-0.02810322,  0.16473363, -0.06574909, ..., -0.05871957,
#          0.05602604,  0.04890444], dtype=float32),
#  array([-0.03545099,  0.19724154,  0.07856277, ..., -0.03292926,
#          0.05814859,  0.09882519], dtype=float32),
#  array([-0.0499066 ,  0.1562894 , -0.04097961, ..., -0.04551654,
#          0.05991203,  0.04728505], dtype=float32),
#  array([ 0.02601222,  0.17359576, -0.00980921, ...,  0.01053683,
#         -0.06824549,  0.06100235], dtype=float32),
#  array([ 0.02757262,  0.19563727,  0.01631955, ...,  0.00792137,
#         -0.05837783,  0.06515611], dtype=float32),
#  array([ 0.07092334,  0.09131397, -0.09953225, ..., -0.05647999,
#          0.00040974,  0.14329048], dtype=float32),
#  array([ 3.5022903e-02,  2.0132089e-01,  1.6790096e-02, ...,
#         -1.8087353e-04, -9.4798587e-02,  5.2694682e-02], dtype=float32),
#  array([ 0.08326954,  0.10031601,  0.01556377, ..., -0.02589754,
#         -0.0562258 ,  0.19860846], dtype=float32),
#  array([ 0.04439306,  0.11124408, -0.07610539, ..., -0.04453728,
#          0.02368459,  0.10861035], dtype=float32),
#  array([-0.1913233 ,  0.37769592, -0.10539454, ..., -0.05812815,
#         -0.17765717,  0.00622507], dtype=float32),
#  array([-0.09400483,  0.2516611 , -0.01895116, ..., -0.155754  ,
#         -0.05932934,  0.08890216], dtype=float32),
#  array([ 0.10685718,  0.17380811,  0.10999692, ...,  0.00851293,
#         -0.12025475,  0.17551185], dtype=float32),
#  array([ 0.0759049 ,  0.10648442,  0.06028914, ..., -0.14886652,
#          0.00715048,  0.06668153], dtype=float32),
#  array([-0.03538973,  0.28922352,  0.03715767, ..., -0.06532114,
#         -0.05282943,  0.08027764], dtype=float32),
#  array([ 0.07666554,  0.18519658,  0.14124158, ..., -0.15773681,
#          0.05522861,  0.15191922], dtype=float32),
#  array([ 0.16412842,  0.14249967,  0.03182452, ..., -0.07904235,
#         -0.08498413,  0.10216834], dtype=float32),
#  array([ 0.1421524 ,  0.04462378,  0.10563048, ...,  0.00884685,
#         -0.23439504,  0.03502961], dtype=float32),
#  array([ 0.10112707,  0.24632983,  0.06338397, ..., -0.10111415,
#         -0.19699992, -0.01037608], dtype=float32),
#  array([ 0.00204803,  0.27911574,  0.06163524, ...,  0.01210757,
#          0.0766141 , -0.00951015], dtype=float32),
#  array([ 0.16239774,  0.37767163,  0.21892883, ..., -0.11961226,
#         -0.14950213, -0.15089642], dtype=float32),
#  array([ 0.09125703,  0.2588677 ,  0.12267441, ..., -0.01297109,
#         -0.1470136 ,  0.08149006], dtype=float32),
#  array([ 0.09789015,  0.29428986,  0.03954884, ..., -0.01430912,
#         -0.22252482,  0.04883968], dtype=float32),
#  array([ 0.16037817,  0.13117121, -0.05306986, ..., -0.07560918,
#         -0.02655896, -0.00547838], dtype=float32),
#  array([ 0.09949052,  0.09726457,  0.05839357, ..., -0.0630338 ,
#          0.05340184,  0.08349067], dtype=float32),
#  array([ 0.09885615,  0.10889129, -0.00785482, ..., -0.07617342,
#          0.0416426 ,  0.04548877], dtype=float32),
#  array([ 0.0755799 ,  0.12930833,  0.12902083, ..., -0.06346793,
#          0.06606872,  0.07990918], dtype=float32),
#  array([ 0.03632654,  0.08231816, -0.08031533, ..., -0.022152  ,
#          0.08624616,  0.28673214], dtype=float32),
#  array([ 0.01921654,  0.13856742, -0.16964202, ..., -0.08970805,
#         -0.0426195 ,  0.03437074], dtype=float32),
#  array([-0.00579192,  0.1258089 , -0.15806234, ..., -0.11301401,
#         -0.04828063,  0.00747965], dtype=float32),
#  array([-0.0070667 ,  0.12502603, -0.15673628, ..., -0.11465104,
#         -0.04803676,  0.0077728 ], dtype=float32),
#  array([ 0.01790661,  0.1531132 , -0.1823524 , ..., -0.10142546,
#         -0.07334664,  0.03810424], dtype=float32),
#  array([ 0.04585769,  0.16688888, -0.01125819, ..., -0.17273602,
#         -0.13466626,  0.07507101], dtype=float32),
#  array([ 0.05282265,  0.19492257, -0.11533788, ..., -0.21228282,
#         -0.10787187,  0.05474392], dtype=float32),
#  array([ 0.07424032,  0.03649038, -0.10897177, ..., -0.05702455,
#         -0.01016307,  0.08431873], dtype=float32),
#  array([ 0.07884319,  0.20499505, -0.07939352, ..., -0.19580683,
#         -0.13237005,  0.04463546], dtype=float32),
#  array([-0.1983909 ,  0.31821927,  0.01608976, ..., -0.01206062,
#         -0.13574283, -0.06789573], dtype=float32),
#  array([-0.19672282,  0.2811438 ,  0.03739224, ..., -0.02902872,
#         -0.11990424, -0.08253962], dtype=float32),
#  array([-0.22503453,  0.234746  ,  0.02380908, ..., -0.17170268,
#         -0.20890516, -0.10143469], dtype=float32),
#  array([0.21500044, 0.22286023, 0.00417405, ..., 0.17273422, 0.049348  ,
#         0.16884212], dtype=float32),
#  array([ 0.10423138,  0.20068073, -0.10384887, ..., -0.04879207,
#         -0.00810504,  0.10765461], dtype=float32),
#  array([ 0.13572255,  0.05759726, -0.11844444, ..., -0.12782021,
#         -0.05003493,  0.0120692 ], dtype=float32),
#  array([ 0.07269987,  0.18334551, -0.16725563, ..., -0.02863936,
#          0.01213116, -0.10816457], dtype=float32),
#  array([ 0.04540228,  0.12939702, -0.02657595, ...,  0.03926136,
#          0.01558923, -0.06003473], dtype=float32),
#  array([ 0.03751231,  0.18454804, -0.11718271, ..., -0.02356186,
#          0.03079094, -0.07865895], dtype=float32),
#  array([-0.0081221 ,  0.09037946, -0.05191921, ..., -0.10468321,
#         -0.04708914,  0.11276024], dtype=float32),
#  array([-0.03410891,  0.07666949, -0.0450257 , ..., -0.10351969,
#         -0.10306265,  0.1420243 ], dtype=float32),
#  array([ 0.06173383,  0.14645487, -0.10207459, ...,  0.02139093,
#         -0.00560905, -0.04567408], dtype=float32),
#  array([-0.011946  ,  0.07409769, -0.05924448, ..., -0.10256396,
#         -0.11457456,  0.16368268], dtype=float32),
#  array([-0.0272268 ,  0.09388793, -0.08177622, ..., -0.10113368,
#         -0.10512759,  0.1183695 ], dtype=float32),
#  array([ 0.05878855,  0.09873288,  0.02444   , ..., -0.03783282,
#         -0.02617911,  0.1228622 ], dtype=float32),
#  array([ 0.01669046,  0.10110848,  0.0875678 , ..., -0.01270475,
#         -0.11567868,  0.11755   ], dtype=float32),
#  array([ 0.01569843,  0.08560103,  0.08177885, ..., -0.04696353,
#         -0.10065301,  0.14995508], dtype=float32),
#  array([ 0.01578966,  0.10885474,  0.00780448, ..., -0.04442212,
#         -0.06985895,  0.0974932 ], dtype=float32),
#  array([ 0.02803533,  0.12105351,  0.02359096, ..., -0.05010218,
#         -0.09115357,  0.11374048], dtype=float32),
#  array([ 0.0144013 ,  0.09726535,  0.05185907, ..., -0.04426263,
#         -0.09366836,  0.10041824], dtype=float32),
#  array([ 0.02384179,  0.07142649,  0.06696092, ..., -0.01921678,
#         -0.08596335,  0.13910168], dtype=float32),
#  array([-0.00221322,  0.05338614, -0.04647143, ...,  0.03728425,
#         -0.11840635,  0.0592041 ], dtype=float32),
#  array([ 0.05940206,  0.08418819, -0.05230603, ...,  0.04699207,
#         -0.14526907,  0.11279448], dtype=float32),
#  array([ 0.06585701,  0.07430189, -0.10889606, ...,  0.05017177,
#         -0.10111383,  0.10806257], dtype=float32),
#  array([ 0.05217813,  0.11147958, -0.08552869, ..., -0.09746139,
#          0.0807323 ,  0.01886094], dtype=float32),
#  array([ 0.08764941,  0.10813697, -0.07320381, ..., -0.14643165,
#          0.06156649,  0.052133  ], dtype=float32),
#  array([ 0.05217739,  0.1055608 , -0.00747878, ..., -0.10238606,
#          0.07434385,  0.02664601], dtype=float32),
#  array([ 0.05217739,  0.1055608 , -0.00747878, ..., -0.10238606,
#          0.07434385,  0.02664601], dtype=float32),
#  array([ 0.09043556,  0.12079167, -0.08523601, ..., -0.09786428,
#          0.11491131,  0.01466571], dtype=float32),
#  array([ 0.04324752,  0.10762547, -0.08831017, ..., -0.1403768 ,
#          0.03777684,  0.00716497], dtype=float32),
#  array([ 0.07562577,  0.09411672,  0.01172421, ..., -0.08181477,
#          0.12412123,  0.01225744], dtype=float32),
#  array([ 0.05389041,  0.11911404, -0.01618001, ..., -0.09339182,
#          0.10521705,  0.02450628], dtype=float32),
#  array([ 0.03529035,  0.22245069, -0.01460759, ..., -0.04512594,
#         -0.02692936,  0.04080112], dtype=float32),
#  array([ 0.04463571,  0.07677739,  0.03174162, ..., -0.06113472,
#          0.09641267,  0.0251614 ], dtype=float32),
#  array([ 0.06177368,  0.20401917, -0.03998747, ..., -0.08992184,
#          0.01539669,  0.00591592], dtype=float32),
#  array([ 0.00295608,  0.09043579,  0.03955372, ..., -0.06776698,
#          0.06082249,  0.04708483], dtype=float32),
#  array([ 0.07056149,  0.09217196, -0.00731586, ..., -0.04302827,
#         -0.03089712, -0.02466168], dtype=float32),
#  array([ 0.08336311,  0.1364259 , -0.03873416, ..., -0.03916001,
#         -0.04444287, -0.01956225], dtype=float32),
#  array([ 0.08335957,  0.13771114, -0.02880247, ..., -0.0362056 ,
#         -0.02557987, -0.03857446], dtype=float32),
#  array([ 0.10192882,  0.11765496, -0.04944115, ..., -0.02025658,
#         -0.09289823,  0.02569189], dtype=float32),
#  array([ 0.13791898,  0.11406904, -0.0520275 , ..., -0.07606371,
#         -0.02962001,  0.170543  ], dtype=float32),
#  array([-0.10325504,  0.281769  ,  0.17034553, ...,  0.00145902,
#          0.09142381,  0.19135545], dtype=float32),
#  array([ 0.0999845 ,  0.17697068, -0.10315431, ..., -0.05724569,
#         -0.04736281,  0.16101244], dtype=float32),
#  array([-0.08841329,  0.30191317,  0.12554625, ..., -0.00919539,
#          0.08873426,  0.23023161], dtype=float32),
#  array([ 0.08584521,  0.16138294,  0.02754934, ..., -0.09953922,
#         -0.18581487,  0.16935809], dtype=float32),
#  array([ 0.08112742,  0.16108154,  0.02885315, ..., -0.09610238,
#         -0.17886038,  0.17175068], dtype=float32),
#  array([ 0.10987891,  0.15750167, -0.04720585, ..., -0.0778989 ,
#         -0.15879205,  0.1941468 ], dtype=float32),
#  array([ 0.04071156,  0.1591837 ,  0.1120747 , ..., -0.08800445,
#         -0.19131002,  0.15374291], dtype=float32),
#  array([ 0.04714984,  0.18034832,  0.07100068, ..., -0.03025589,
#         -0.15657808,  0.06979406], dtype=float32),
#  array([ 0.00494477,  0.23882608, -0.01440517, ..., -0.07624143,
#         -0.10163248,  0.05344778], dtype=float32),
#  array([ 0.05425197,  0.17216924,  0.06792241, ..., -0.04072594,
#         -0.16690424,  0.02010938], dtype=float32),
#  array([ 0.05813978,  0.17405796,  0.07788119, ..., -0.02621063,
#         -0.17280018,  0.07827315], dtype=float32),
#  array([ 0.07401364,  0.1655667 ,  0.07052682, ..., -0.03007331,
#         -0.16457456,  0.06966857], dtype=float32),
#  array([ 0.02987621,  0.12993526, -0.20087455, ..., -0.05413379,
#         -0.21151975,  0.02371727], dtype=float32),
#  array([ 0.00980531,  0.15449375, -0.19839257, ..., -0.04213029,
#         -0.2255715 ,  0.0443465 ], dtype=float32),
#  array([ 0.05006869,  0.12926789, -0.21532303, ..., -0.08571588,
#         -0.1907501 ,  0.00923922], dtype=float32),
#  array([-0.0745682 ,  0.19324748,  0.11853829, ...,  0.05910313,
#         -0.08456627, -0.15097597], dtype=float32),
#  array([-0.13823448,  0.23676938,  0.08765401, ..., -0.02573609,
#          0.00978229, -0.15778923], dtype=float32),
#  array([ 0.06629109,  0.19827798, -0.12161741, ...,  0.11424762,
#         -0.0380099 , -0.04309431], dtype=float32),
#  array([-0.09583632,  0.23084153,  0.05177457, ..., -0.13237713,
#         -0.00756784,  0.08388539], dtype=float32),
#  array([ 0.07536132,  0.18217605, -0.08160425, ...,  0.05237756,
#          0.00311087,  0.1237627 ], dtype=float32),
#  array([ 0.10901731,  0.11949313,  0.04079874, ..., -0.22540502,
#          0.07338632,  0.02141538], dtype=float32),
#  array([ 0.0844283 ,  0.26498553, -0.0026855 , ...,  0.00908328,
#         -0.03713857,  0.21661654], dtype=float32),
#  array([-0.09880003,  0.2901797 , -0.08052798, ..., -0.09241614,
#         -0.12327776, -0.12829746], dtype=float32),
#  array([ 0.09906301,  0.31937367,  0.0226535 , ...,  0.00741706,
#         -0.05737195,  0.22688767], dtype=float32),
#  array([ 0.0971728 ,  0.28875297, -0.00326287, ..., -0.02048337,
#         -0.00998918,  0.19978182], dtype=float32),
#  array([ 0.1365011 ,  0.32036424,  0.01252669, ...,  0.0763128 ,
#         -0.05940761,  0.13821481], dtype=float32),
#  array([ 0.12091336,  0.34573144, -0.06380751, ..., -0.00552719,
#         -0.04197495,  0.2325037 ], dtype=float32),
#  array([ 0.09655418,  0.28502926, -0.02737048, ..., -0.03377255,
#         -0.04447336,  0.16912127], dtype=float32),
#  array([ 0.10896149,  0.06706794,  0.00657894, ..., -0.00859205,
#          0.16640548,  0.10695385], dtype=float32),
#  array([ 0.08620133,  0.28112352,  0.03700839, ..., -0.01423807,
#         -0.09250401,  0.18378793], dtype=float32),
#  array([ 0.0965879 ,  0.27715683,  0.04370034, ..., -0.02084666,
#         -0.04791114,  0.19239388], dtype=float32),
#  array([ 0.08088821,  0.33141878, -0.05597524, ...,  0.01568509,
#         -0.05554882,  0.24618915], dtype=float32),
#  array([ 0.12868844,  0.17926258,  0.1521433 , ...,  0.04466709,
#         -0.01174256,  0.26564226], dtype=float32),
#  array([ 0.07391744,  0.2704411 ,  0.01232075, ..., -0.01631871,
#         -0.07405523,  0.17846577], dtype=float32),
#  array([ 0.13676667,  0.0492791 , -0.03477651, ..., -0.08604669,
#          0.02760646,  0.07795157], dtype=float32),
#  array([ 0.07138249,  0.06530529, -0.07995696, ..., -0.0499493 ,
#          0.05284991,  0.07496659], dtype=float32),
#  array([ 0.0839008 ,  0.2603321 ,  0.00587625, ..., -0.01939663,
#         -0.09037502,  0.17788163], dtype=float32),
#  array([ 0.11547173,  0.28192055,  0.04611494, ..., -0.00760527,
#         -0.04705677,  0.23134239], dtype=float32),
#  array([ 0.0752053 ,  0.25965476, -0.00141773, ..., -0.0150621 ,
#         -0.09217191,  0.17867912], dtype=float32),
#  array([ 0.1690277 ,  0.11517622,  0.03154884, ...,  0.15772355,
#         -0.23606102,  0.05987878], dtype=float32),
#  array([ 0.04497796,  0.17964613,  0.16303197, ..., -0.07711127,
#         -0.07828205,  0.12431834], dtype=float32),
#  array([ 0.14510547,  0.3661763 ,  0.02875514, ...,  0.04148452,
#         -0.05773141,  0.1512682 ], dtype=float32),
#  array([ 0.01538436,  0.04710757,  0.08285351, ..., -0.03207109,
#         -0.39443707,  0.05016626], dtype=float32),
#  array([ 0.1252103 ,  0.02575257,  0.05374578, ..., -0.04348713,
#         -0.24826914, -0.04646222], dtype=float32),
#  array([ 0.12338737,  0.02300368,  0.07263841, ..., -0.0046788 ,
#         -0.23932606, -0.00268799], dtype=float32),
#  array([0.09199145, 0.12564139, 0.00630899, ..., 0.00900699, 0.08616445,
#         0.01047231], dtype=float32),
#  array([ 0.14933997,  0.3872747 ,  0.2693198 , ..., -0.11864173,
#         -0.1258647 , -0.142395  ], dtype=float32),
#  array([ 0.09932403,  0.23375705, -0.10378423, ..., -0.06505784,
#         -0.08155893,  0.07768843], dtype=float32),
#  array([ 0.12401355,  0.33900902, -0.15801227, ..., -0.07346244,
#         -0.13048267,  0.04511388], dtype=float32),
#  array([ 0.09514228,  0.29730046, -0.2142025 , ..., -0.12169672,
#         -0.08322516,  0.00327409], dtype=float32),
#  array([ 0.12367469,  0.3389117 , -0.15845644, ..., -0.07247809,
#         -0.13198778,  0.04675224], dtype=float32),
#  array([ 0.13627294,  0.22337985, -0.1669133 , ..., -0.06410085,
#         -0.06388231,  0.03430152], dtype=float32),
#  array([ 0.1528051 ,  0.2667626 , -0.13226493, ..., -0.08213512,
#         -0.10858221,  0.04193421], dtype=float32),
#  array([ 0.11268622,  0.32139155, -0.24398778, ..., -0.12493558,
#         -0.12149277, -0.02344252], dtype=float32),
#  array([ 0.10480339,  0.2604376 , -0.09635982, ..., -0.07012109,
#         -0.10020515,  0.06075288], dtype=float32),
#  array([ 0.082454  ,  0.16753572, -0.11766481, ..., -0.12341342,
#         -0.11256757,  0.10978843], dtype=float32),
#  array([ 0.08313193,  0.18081869, -0.12823392, ..., -0.09605679,
#         -0.10644236,  0.11725705], dtype=float32),
#  array([ 0.06373269,  0.13855398, -0.10829671, ..., -0.07388348,
#         -0.08892627,  0.14700925], dtype=float32),
#  array([ 0.06333284,  0.14195132, -0.1048426 , ..., -0.07166432,
#         -0.09300075,  0.14922683], dtype=float32),
#  array([ 0.09872648,  0.18236615, -0.13592312, ..., -0.07809079,
#         -0.1270317 ,  0.14315213], dtype=float32),
#  array([ 0.05249693,  0.19444156, -0.09503391, ..., -0.12258938,
#         -0.06952256,  0.14591907], dtype=float32),
#  array([ 0.07556563,  0.20042677, -0.28242728, ..., -0.19003032,
#         -0.12841053,  0.07452537], dtype=float32),
#  array([ 0.10948956,  0.16213353, -0.21028624, ..., -0.15856452,
#         -0.06499958,  0.08221399], dtype=float32),
#  array([ 0.0728675 ,  0.23302844, -0.03767389, ..., -0.10232188,
#         -0.06693564,  0.18443163], dtype=float32),
#  array([ 0.08093075,  0.25787136, -0.1914168 , ..., -0.11975294,
#         -0.18081447,  0.06590416], dtype=float32),
#  array([ 0.13555796,  0.20023438, -0.17310171, ..., -0.10711312,
#         -0.1405019 ,  0.08923372], dtype=float32),
#  array([ 0.07135855,  0.13600202, -0.12697335, ..., -0.1487052 ,
#         -0.12217811,  0.12625138], dtype=float32),
#  array([ 0.07269988,  0.18334562, -0.16725557, ..., -0.02863934,
#          0.01213124, -0.10816448], dtype=float32),
#  array([ 0.03161433,  0.17589176, -0.0763774 , ..., -0.01736309,
#          0.04275976, -0.06488634], dtype=float32),
#  array([ 0.07269988,  0.18334562, -0.16725557, ..., -0.02863934,
#          0.01213124, -0.10816448], dtype=float32),
#  array([ 0.05987721,  0.16105707, -0.07780813, ..., -0.01187938,
#          0.0618535 , -0.05534874], dtype=float32),
#  array([-0.02761495,  0.1077259 , -0.07670906, ..., -0.10136447,
#         -0.09403907,  0.12693898], dtype=float32),
#  array([-0.03568858,  0.16513377,  0.0099761 , ..., -0.11641009,
#         -0.1287075 ,  0.12999682], dtype=float32),
#  array([-0.00024804,  0.10162961,  0.0537152 , ..., -0.04521343,
#         -0.08850927,  0.13556327], dtype=float32),
#  array([ 0.00429464,  0.10213305,  0.05935413, ..., -0.0442693 ,
#         -0.09356867,  0.1372739 ], dtype=float32),
#  array([ 0.01569842,  0.08560107,  0.08177885, ..., -0.04696352,
#         -0.10065303,  0.1499551 ], dtype=float32),
#  array([ 0.02234225,  0.11318053, -0.00300966, ..., -0.03474038,
#         -0.09939586,  0.15450166], dtype=float32),
#  array([ 0.09679424,  0.10856648, -0.12002358, ...,  0.0454501 ,
#         -0.12524973,  0.10317416], dtype=float32),
#  array([ 0.00213012,  0.04425139, -0.03830984, ...,  0.06246556,
#         -0.09810187,  0.09307238], dtype=float32),
#  array([-0.01621763,  0.06685346, -0.03993069, ...,  0.05799747,
#         -0.08639044,  0.07216667], dtype=float32),
#  array([ 0.070819  ,  0.15070236, -0.12195557, ..., -0.0028932 ,
#         -0.13420092,  0.05780033], dtype=float32),
#  array([-0.00092565,  0.053695  , -0.04679196, ...,  0.03491075,
#         -0.11660958,  0.05855452], dtype=float32),
#  array([ 0.05075646,  0.13039558, -0.07816   , ...,  0.03525609,
#         -0.14256075,  0.08435268], dtype=float32),
#  array([ 0.05217742,  0.10556086, -0.00747877, ..., -0.10238608,
#          0.0743438 ,  0.02664599], dtype=float32),
#  array([ 0.09952406,  0.13670975, -0.06766249, ..., -0.15739682,
#         -0.01017611,  0.06491143], dtype=float32),
#  array([ 7.7509001e-02,  9.8190106e-02, -8.5630000e-02, ...,
#         -1.3808407e-01,  1.1623706e-01,  9.5165356e-05], dtype=float32),
#  array([ 0.06235713,  0.1233038 ,  0.00725124, ..., -0.08495672,
#          0.0673454 ,  0.00124683], dtype=float32),
#  array([ 0.10873737,  0.10244302, -0.04045646, ..., -0.08889343,
#          0.1103544 , -0.00361538], dtype=float32),
#  array([ 0.08170035,  0.13054504, -0.05349233, ..., -0.13028277,
#          0.04789608, -0.00172354], dtype=float32),
#  array([ 0.08024871,  0.11619329,  0.00583072, ..., -0.08984451,
#          0.10862531,  0.03509481], dtype=float32),
#  array([ 0.0497877 ,  0.09494831, -0.01421715, ..., -0.11255077,
#          0.11014491,  0.00636575], dtype=float32),
#  array([ 0.04744051,  0.07840378, -0.02636614, ..., -0.14033864,
#          0.09463026, -0.01424126], dtype=float32),
#  array([ 0.04725945,  0.07858272, -0.02386405, ..., -0.13826077,
#          0.09686907, -0.01404837], dtype=float32),
#  array([ 0.00284186,  0.08328892,  0.01578133, ..., -0.05994171,
#          0.05549303,  0.05957628], dtype=float32),
#  array([ 0.06580827,  0.12938114, -0.02438996, ..., -0.08980857,
#          0.1076292 ,  0.06315272], dtype=float32)]

# %%
x_binary_test = np.array(list(ne_e_test_data['embeddings']))
y_binary_test = list(ne_e_test_data['enzyme_nonenzyme'])
# Out:
# <ipython-input-141-97cbe74f8b9a>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x_binary_test = np.array(list(ne_e_test_data['embeddings']))

# %%
x_binary_test.shape
# Out:
# (26335,)

# %%
x_binary_test = x_binary_test.reshape(1, -1)

# %%
x_binary_test.shape
# Out:
# (1, 26335)

# %%
x_binary_test = list(ne_e_test_data['embeddings'])

# %%
x_binary_test
# Out:
# [array([ 0.12746994,  0.27281544,  0.06692323, ...,  0.03192677,
#         -0.12083121,  0.10100751], dtype=float32),
#  array([ 0.12582903,  0.11324516,  0.11739114, ..., -0.10598259,
#         -0.09380031,  0.09344083], dtype=float32),
#  array([ 0.13101612,  0.30415857,  0.17695493, ..., -0.1529716 ,
#         -0.10064235,  0.05371748], dtype=float32),
#  array([ 0.02620515,  0.21668276,  0.05241565, ..., -0.0518866 ,
#         -0.02595983, -0.06790142], dtype=float32),
#  array([ 0.07479797, -0.00678012,  0.0770188 , ..., -0.09401439,
#         -0.16186218, -0.05884096], dtype=float32),
#  array([ 0.16155864,  0.15980445, -0.0059483 , ..., -0.12044955,
#         -0.1110381 ,  0.25093448], dtype=float32),
#  array([-0.08676058,  0.17472704, -0.14077938, ..., -0.01626236,
#         -0.05927157, -0.01815291], dtype=float32),
#  array([-0.00168251,  0.22733687, -0.00960301, ..., -0.17274092,
#          0.04870052,  0.0334609 ], dtype=float32),
#  array([ 0.05386835,  0.3409739 , -0.05055678, ..., -0.09174938,
#         -0.14551114,  0.03144156], dtype=float32),
#  array([-0.02344199,  0.18911996,  0.20865126, ..., -0.07064731,
#         -0.07448851, -0.0501512 ], dtype=float32),
#  array([ 0.09081493,  0.08879563, -0.13010713, ..., -0.07828739,
#          0.09493093, -0.05747114], dtype=float32),
#  array([ 0.03212073,  0.25158703,  0.0892169 , ..., -0.03477114,
#          0.01295989,  0.11586889], dtype=float32),
#  array([ 0.12199517,  0.18151395, -0.06676664, ..., -0.01700892,
#          0.05040547,  0.11410113], dtype=float32),
#  array([-0.08588733,  0.09010991,  0.16820973, ..., -0.0650363 ,
#         -0.11938175,  0.04160687], dtype=float32),
#  array([-0.05397262,  0.05617085, -0.04073084, ..., -0.02187811,
#         -0.03898628,  0.09664018], dtype=float32),
#  array([ 0.07800987,  0.11569427, -0.03748494, ..., -0.08455689,
#         -0.05606881,  0.2546402 ], dtype=float32),
#  array([ 0.02393015,  0.17435403, -0.02548681, ..., -0.09845455,
#         -0.00473615,  0.13016255], dtype=float32),
#  array([ 0.12618868,  0.12496985, -0.0801181 , ..., -0.10386841,
#         -0.0761207 ,  0.04038953], dtype=float32),
#  array([-0.0556748 ,  0.14706284, -0.01857577, ..., -0.03214516,
#          0.06021264, -0.01599133], dtype=float32),
#  array([-0.0408421 ,  0.23106675,  0.05107047, ..., -0.15988092,
#         -0.20001626,  0.17207551], dtype=float32),
#  array([-0.05119038,  0.14584965, -0.03172577, ..., -0.01321754,
#         -0.04655659,  0.00541404], dtype=float32),
#  array([ 0.04707152,  0.06630967,  0.05083768, ..., -0.10685203,
#          0.20704834,  0.00484267], dtype=float32),
#  array([-0.08302564,  0.2550081 ,  0.03160182, ..., -0.06407085,
#          0.06423152, -0.02148802], dtype=float32),
#  array([ 0.03409991,  0.2842658 ,  0.00310283, ..., -0.00153249,
#         -0.02908522,  0.18453881], dtype=float32),
#  array([ 0.06875871,  0.06855331, -0.14210314, ..., -0.14952895,
#          0.02823814,  0.0366088 ], dtype=float32),
#  array([ 0.08282692,  0.09385992,  0.06894775, ..., -0.0726162 ,
#         -0.00374927,  0.02078794], dtype=float32),
#  array([-0.04185464,  0.32520723,  0.17715137, ..., -0.05400571,
#          0.01504996,  0.05942492], dtype=float32),
#  array([ 0.07873748,  0.08482758, -0.06360897, ..., -0.09282423,
#         -0.05347299,  0.06237409], dtype=float32),
#  array([ 0.03140029,  0.13934496,  0.0448583 , ..., -0.00937204,
#         -0.21113394,  0.17962158], dtype=float32),
#  array([-0.11774212, -0.02616799,  0.01097338, ..., -0.07185459,
#         -0.08549445,  0.13276543], dtype=float32),
#  array([ 0.03774082,  0.12272622,  0.00686684, ..., -0.02195711,
#         -0.04483243,  0.05532301], dtype=float32),
#  array([ 0.08584646, -0.03397616,  0.02482531, ..., -0.10262835,
#          0.16479225,  0.25734416], dtype=float32),
#  array([ 0.01389541,  0.08447769, -0.09851353, ..., -0.10867345,
#         -0.16327992,  0.11544044], dtype=float32),
#  array([-0.05294674,  0.25294963, -0.00992672, ..., -0.03026475,
#         -0.09962948,  0.105144  ], dtype=float32),
#  array([ 0.10634867,  0.10443152, -0.07619237, ...,  0.0662737 ,
#         -0.18047279,  0.24464408], dtype=float32),
#  array([ 0.04494971,  0.12908255,  0.08951259, ..., -0.10883437,
#         -0.05032612,  0.17136031], dtype=float32),
#  array([-0.05117968,  0.36321366, -0.08623495, ..., -0.00695762,
#         -0.17767604,  0.05680528], dtype=float32),
#  array([ 0.04071086,  0.19298765, -0.08025124, ...,  0.07405926,
#         -0.15025815,  0.14640096], dtype=float32),
#  array([ 0.06529132, -0.02872422,  0.08305755, ..., -0.0300427 ,
#         -0.03447206,  0.20021586], dtype=float32),
#  array([ 0.10466831,  0.18236174,  0.13279174, ..., -0.1222855 ,
#          0.00974496,  0.0592649 ], dtype=float32),
#  array([ 0.18349649,  0.32568926, -0.10926195, ...,  0.01397889,
#          0.00080862,  0.06918445], dtype=float32),
#  array([ 0.00829772,  0.07864327, -0.06845561, ...,  0.15162997,
#         -0.18492718,  0.1028145 ], dtype=float32),
#  array([ 0.03235992,  0.15519391,  0.08527905, ..., -0.04469622,
#         -0.04811539,  0.12483492], dtype=float32),
#  array([ 0.03669433,  0.22162928,  0.12777202, ...,  0.07378137,
#         -0.04504135,  0.14851691], dtype=float32),
#  array([-0.05687763,  0.27036595, -0.00150571, ..., -0.04661657,
#         -0.1152323 ,  0.03725291], dtype=float32),
#  array([ 0.06140495,  0.11142214, -0.00380059, ..., -0.09521655,
#          0.04749123,  0.04711342], dtype=float32),
#  array([-0.00585382,  0.11649451, -0.06271199, ..., -0.10690926,
#         -0.0457649 ,  0.02951806], dtype=float32),
#  array([-0.06449496,  0.22217509,  0.0560176 , ..., -0.02474403,
#         -0.06755628,  0.15483548], dtype=float32),
#  array([ 0.05401842,  0.08253632,  0.05742294, ..., -0.05678816,
#         -0.06493905,  0.07638738], dtype=float32),
#  array([ 0.06760329,  0.27685356,  0.23079365, ..., -0.13902031,
#         -0.08934916,  0.16463424], dtype=float32),
#  array([ 0.24198742,  0.18526855,  0.1751771 , ..., -0.06322701,
#         -0.16421185,  0.30567652], dtype=float32),
#  array([-0.09687702,  0.15433423, -0.29849803, ..., -0.1209119 ,
#         -0.15620641,  0.09728729], dtype=float32),
#  array([-0.00526488,  0.19854704, -0.22186701, ...,  0.19506083,
#         -0.04369731,  0.12992151], dtype=float32),
#  array([-0.10017274, -0.00564246, -0.05984658, ...,  0.01380808,
#         -0.07798218, -0.05848726], dtype=float32),
#  array([ 0.08175758,  0.08391992, -0.13765895, ..., -0.07655115,
#         -0.12179259,  0.16132155], dtype=float32),
#  array([ 0.06354153,  0.19653249, -0.1314372 , ..., -0.09851202,
#         -0.21784441,  0.12020856], dtype=float32),
#  array([ 0.01153362,  0.09294046, -0.09080734, ..., -0.07118899,
#         -0.077744  , -0.07514137], dtype=float32),
#  array([-0.02471618,  0.26030743,  0.15680131, ..., -0.01850267,
#         -0.02556833,  0.11160857], dtype=float32),
#  array([ 0.04282105,  0.09136026,  0.12447304, ..., -0.14606111,
#         -0.03376241,  0.0428042 ], dtype=float32),
#  array([ 0.10395262,  0.0834736 , -0.03146138, ..., -0.11757933,
#          0.03518251,  0.05242244], dtype=float32),
#  array([ 0.12421265, -0.02247445,  0.09171052, ...,  0.06925351,
#          0.04736974,  0.17981742], dtype=float32),
#  array([-0.02420825,  0.10974076, -0.10258887, ..., -0.03047539,
#         -0.12132655,  0.08650941], dtype=float32),
#  array([ 0.08301067,  0.12656118, -0.03309018, ..., -0.03365676,
#         -0.14931487,  0.04464954], dtype=float32),
#  array([ 0.01397137,  0.08227161,  0.0180832 , ..., -0.0614258 ,
#          0.25220758,  0.09697956], dtype=float32),
#  array([ 0.1116967 ,  0.08152584,  0.01319132, ..., -0.17048201,
#         -0.177015  ,  0.09538671], dtype=float32),
#  array([ 0.03140062,  0.14209533,  0.00559003, ..., -0.05758023,
#         -0.00329855,  0.13845265], dtype=float32),
#  array([ 0.02506501,  0.1721601 , -0.09067529, ..., -0.16101253,
#         -0.14374499,  0.17319107], dtype=float32),
#  array([ 0.1148125 ,  0.10412161, -0.09607985, ...,  0.01433243,
#         -0.14767404,  0.13904351], dtype=float32),
#  array([ 0.01618287,  0.24850348,  0.15176338, ..., -0.02846862,
#          0.03309115,  0.1643367 ], dtype=float32),
#  array([ 0.08006394,  0.1288493 ,  0.11739056, ..., -0.09627321,
#         -0.02436384,  0.18358609], dtype=float32),
#  array([ 0.07045162,  0.07925801, -0.03087061, ...,  0.02544925,
#         -0.15910943,  0.04197936], dtype=float32),
#  array([-0.00357887,  0.06083508,  0.14265133, ...,  0.05547332,
#         -0.02252791, -0.0213482 ], dtype=float32),
#  array([ 0.0501718 ,  0.14968936,  0.09685841, ..., -0.03576322,
#          0.00876956,  0.04818991], dtype=float32),
#  array([-0.03645053,  0.1426871 , -0.0753132 , ..., -0.06346374,
#         -0.04047862, -0.02655027], dtype=float32),
#  array([ 0.06539521,  0.11595684, -0.10150375, ..., -0.13291846,
#         -0.11816939, -0.25340602], dtype=float32),
#  array([ 0.10732917,  0.1270721 , -0.04352747, ..., -0.02035019,
#         -0.26832932,  0.07043739], dtype=float32),
#  array([-0.00594479,  0.09236501, -0.00696285, ..., -0.04612393,
#          0.05892185,  0.08653317], dtype=float32),
#  array([ 0.09181061,  0.29015222, -0.12736407, ...,  0.17638896,
#         -0.11813001,  0.21475007], dtype=float32),
#  array([ 0.03906853,  0.20795515,  0.02783437, ...,  0.04111014,
#         -0.20755321,  0.21062367], dtype=float32),
#  array([ 0.00893752,  0.17943268, -0.00152857, ...,  0.0159138 ,
#         -0.03876936, -0.07491872], dtype=float32),
#  array([ 0.04653336,  0.15393268, -0.09745177, ..., -0.0049691 ,
#         -0.07916702,  0.07904744], dtype=float32),
#  array([ 0.06757555,  0.11253935, -0.13181145, ..., -0.0754905 ,
#         -0.0539827 ,  0.33361286], dtype=float32),
#  array([-0.02458163,  0.0169402 , -0.04070748, ...,  0.00641022,
#          0.1475015 ,  0.08992372], dtype=float32),
#  array([ 0.03108606,  0.02538463, -0.11913393, ...,  0.08289541,
#         -0.09956546,  0.12128053], dtype=float32),
#  array([ 0.06135347,  0.13574915, -0.00270159, ..., -0.04350571,
#          0.06737888,  0.15591455], dtype=float32),
#  array([-0.02858786,  0.21837215,  0.00850647, ..., -0.0555024 ,
#         -0.07228234,  0.15566829], dtype=float32),
#  array([-0.12050846,  0.10711602, -0.01799098, ..., -0.01916752,
#         -0.09154937,  0.33470383], dtype=float32),
#  array([ 0.11798833,  0.21988988, -0.01642097, ..., -0.05042712,
#         -0.05243138,  0.10373569], dtype=float32),
#  array([ 0.01951672,  0.29608405, -0.00393446, ..., -0.10690758,
#         -0.09194094,  0.20413505], dtype=float32),
#  array([ 0.10965391,  0.29340237, -0.0971119 , ...,  0.06521875,
#         -0.0844257 ,  0.11221949], dtype=float32),
#  array([ 0.06388736,  0.18799007, -0.02832131, ...,  0.06908949,
#         -0.17767937,  0.10421363], dtype=float32),
#  array([ 0.09505212,  0.06647801,  0.04226826, ..., -0.09183588,
#         -0.04147106, -0.01876113], dtype=float32),
#  array([ 0.0869231 ,  0.20031017, -0.04999093, ..., -0.12979765,
#         -0.08024775,  0.13752092], dtype=float32),
#  array([ 0.01628772,  0.30980453, -0.04938107, ..., -0.00388719,
#         -0.18256508,  0.04167381], dtype=float32),
#  array([ 0.1436556 ,  0.15926427,  0.13192339, ..., -0.02330843,
#         -0.05462028, -0.02428106], dtype=float32),
#  array([-0.03902956,  0.17832087,  0.23400518, ..., -0.06173328,
#         -0.01933577,  0.07465714], dtype=float32),
#  array([ 0.03197099,  0.12026121,  0.06384606, ..., -0.00243047,
#         -0.17698173, -0.06619643], dtype=float32),
#  array([ 0.05248459,  0.07823691,  0.00380299, ..., -0.08630919,
#         -0.02801252,  0.05149214], dtype=float32),
#  array([ 0.03754479,  0.1082134 , -0.02246613, ..., -0.07104868,
#         -0.03600388,  0.02933481], dtype=float32),
#  array([ 0.04929988,  0.13588274, -0.00299637, ...,  0.02214747,
#         -0.12952438,  0.12421895], dtype=float32),
#  array([-0.11334065,  0.41018245,  0.00892473, ..., -0.02043692,
#         -0.28534466, -0.04774669], dtype=float32),
#  array([-0.24672711,  0.03280798,  0.09478306, ..., -0.14587308,
#         -0.10142457, -0.21976098], dtype=float32),
#  array([ 0.00870598,  0.00778413,  0.10353821, ..., -0.02815133,
#          0.0622388 ,  0.11223373], dtype=float32),
#  array([ 0.01538436,  0.04710757,  0.08285351, ..., -0.03207109,
#         -0.39443707,  0.05016626], dtype=float32),
#  array([ 0.12299953,  0.16212855,  0.00970243, ..., -0.17941162,
#         -0.16802792,  0.07126536], dtype=float32),
#  array([ 0.10721333,  0.06855682, -0.11912461, ...,  0.11019769,
#          0.0472106 , -0.2845563 ], dtype=float32),
#  array([ 0.13150513,  0.24533361, -0.09034252, ...,  0.03596106,
#         -0.15885672,  0.09007712], dtype=float32),
#  array([ 0.09174496,  0.02708158, -0.14154658, ..., -0.14234021,
#          0.05123486,  0.06275676], dtype=float32),
#  array([ 0.00942962,  0.1580857 ,  0.00744824, ...,  0.11027841,
#         -0.07373612,  0.01791982], dtype=float32),
#  array([ 0.19118999,  0.06967157,  0.0799949 , ..., -0.07223488,
#         -0.0857951 ,  0.07305426], dtype=float32),
#  array([-0.0071528 ,  0.25198543,  0.1139334 , ..., -0.01920048,
#          0.11416662,  0.12452821], dtype=float32),
#  array([ 0.06707866,  0.1974283 , -0.04140879, ..., -0.10653367,
#          0.00767836,  0.12108192], dtype=float32),
#  array([ 0.09505287,  0.14264053, -0.02179225, ...,  0.06630803,
#          0.06141001,  0.34172338], dtype=float32),
#  array([-0.02353061,  0.21588542, -0.06734909, ..., -0.0576807 ,
#         -0.01910743,  0.06030193], dtype=float32),
#  array([-0.008487  ,  0.24443305, -0.03877594, ..., -0.0743348 ,
#         -0.0414416 , -0.00635439], dtype=float32),
#  array([-0.05213063,  0.40130597,  0.16481173, ..., -0.13011526,
#         -0.18210825,  0.12012789], dtype=float32),
#  array([-0.02458202, -0.01080877, -0.0719134 , ..., -0.10421117,
#         -0.03368763,  0.08414949], dtype=float32),
#  array([ 0.06521687,  0.12289862, -0.03828433, ..., -0.12788238,
#         -0.02051933,  0.06552027], dtype=float32),
#  array([ 0.01237219,  0.01526025, -0.11212473, ...,  0.13574693,
#         -0.03909971,  0.13011931], dtype=float32),
#  array([ 0.08175003,  0.13178931, -0.07022862, ..., -0.14416166,
#         -0.06149024,  0.14720193], dtype=float32),
#  array([ 0.23427637,  0.198959  , -0.12033738, ..., -0.08030283,
#         -0.17149597,  0.0803288 ], dtype=float32),
#  array([ 0.20029132,  0.27266204, -0.04490459, ...,  0.02426905,
#         -0.05435608,  0.11814583], dtype=float32),
#  array([ 0.08122912,  0.12290803, -0.02489212, ..., -0.02949606,
#         -0.0940951 ,  0.06350858], dtype=float32),
#  array([-0.07926202,  0.29575107, -0.027268  , ..., -0.01695023,
#         -0.07703245,  0.05660836], dtype=float32),
#  array([ 0.1381134 ,  0.29823324,  0.13208866, ..., -0.09105033,
#         -0.29604653,  0.0700414 ], dtype=float32),
#  array([ 0.08727273,  0.04914735, -0.01237944, ...,  0.12495378,
#          0.09802234, -0.21413139], dtype=float32),
#  array([-0.00296748,  0.24193844,  0.02345033, ..., -0.01172734,
#         -0.0194865 ,  0.15031   ], dtype=float32),
#  array([ 0.23852496,  0.05399924,  0.02189211, ..., -0.08750035,
#         -0.11602806,  0.12567124], dtype=float32),
#  array([-0.11503871,  0.15477726, -0.06778927, ..., -0.04300191,
#         -0.08946486,  0.17793986], dtype=float32),
#  array([ 0.02068272,  0.00277581,  0.05141441, ..., -0.03198222,
#          0.01531522,  0.18142186], dtype=float32),
#  array([ 0.02985141,  0.20453154,  0.09965474, ...,  0.00032213,
#         -0.00963936,  0.03424637], dtype=float32),
#  array([ 0.02002993,  0.15042815,  0.07874003, ..., -0.04783913,
#         -0.10086434,  0.10111784], dtype=float32),
#  array([ 0.13827923,  0.4338122 , -0.01325807, ..., -0.06104947,
#          0.01987289,  0.0970738 ], dtype=float32),
#  array([-0.1611519 ,  0.26425582,  0.0624295 , ..., -0.11343394,
#          0.03391137, -0.00248815], dtype=float32),
#  array([ 0.07598393,  0.03273526,  0.02129067, ..., -0.14364152,
#          0.04355284,  0.04208663], dtype=float32),
#  array([-0.03971929,  0.12102903, -0.11053159, ..., -0.09947105,
#         -0.00524542,  0.0564362 ], dtype=float32),
#  array([-0.00113788,  0.19444406,  0.00950763, ...,  0.15429613,
#         -0.08382381,  0.12974906], dtype=float32),
#  array([ 0.09855147,  0.09770661, -0.02004851, ..., -0.11389943,
#         -0.1729305 , -0.01596192], dtype=float32),
#  array([-0.05587635,  0.32933503, -0.18882948, ..., -0.05767997,
#         -0.14210355,  0.15610664], dtype=float32),
#  array([-0.05166658,  0.11240645,  0.05716394, ..., -0.00373463,
#          0.0538505 ,  0.09979001], dtype=float32),
#  array([ 0.12815464,  0.20822029, -0.03916329, ..., -0.06323022,
#         -0.00063673,  0.18581623], dtype=float32),
#  array([-0.02458576,  0.05866187,  0.11628489, ..., -0.04093863,
#         -0.08838038,  0.1751564 ], dtype=float32),
#  array([-0.02914518,  0.12670808,  0.11596856, ..., -0.0300149 ,
#         -0.18311985,  0.01978726], dtype=float32),
#  array([ 0.06560037,  0.08574254, -0.03909984, ..., -0.03645049,
#         -0.22114292,  0.15455322], dtype=float32),
#  array([-0.07656823,  0.18013883,  0.14382175, ...,  0.04619952,
#         -0.06966562,  0.03927773], dtype=float32),
#  array([ 0.03899269, -0.01385556,  0.06786115, ..., -0.09979054,
#          0.0733245 ,  0.04827093], dtype=float32),
#  array([ 0.06329718,  0.17080815, -0.14539516, ..., -0.1281562 ,
#         -0.14199398,  0.11400195], dtype=float32),
#  array([ 0.1534985 ,  0.1319148 ,  0.0328487 , ..., -0.04795292,
#         -0.08333796,  0.23705906], dtype=float32),
#  array([ 0.05831287, -0.13334268, -0.02042375, ..., -0.03543988,
#          0.04635142,  0.06696058], dtype=float32),
#  array([ 0.04495189,  0.11996307, -0.06557694, ..., -0.06360307,
#         -0.0563748 , -0.03344177], dtype=float32),
#  array([ 0.11504988,  0.23645099, -0.1426682 , ..., -0.07492386,
#         -0.1561407 , -0.07004187], dtype=float32),
#  array([ 0.00672764,  0.0419386 , -0.1288322 , ..., -0.2569615 ,
#         -0.11954225, -0.01036795], dtype=float32),
#  array([0.0795308 , 0.19630203, 0.12518524, ..., 0.01710298, 0.06582567,
#         0.08923697], dtype=float32),
#  array([ 0.03219539,  0.06244911,  0.00631129, ..., -0.0888243 ,
#         -0.06024028,  0.13145514], dtype=float32),
#  array([ 0.1773804 ,  0.2328953 ,  0.19746026, ...,  0.03894834,
#         -0.06288625,  0.13950674], dtype=float32),
#  array([ 0.05566864,  0.13674597,  0.1476633 , ...,  0.0441508 ,
#         -0.03307233,  0.21512057], dtype=float32),
#  array([ 0.07390232,  0.11100296,  0.15561195, ...,  0.04756419,
#         -0.04851537,  0.10002088], dtype=float32),
#  array([0.01935528, 0.16393988, 0.08875776, ..., 0.0469504 , 0.03928976,
#         0.22266176], dtype=float32),
#  array([-0.06731572,  0.13520633, -0.11055542, ..., -0.04306877,
#         -0.02171023,  0.02377208], dtype=float32),
#  array([-0.0445218 ,  0.24545698,  0.13305362, ..., -0.06804576,
#         -0.11076786,  0.04807817], dtype=float32),
#  array([ 0.0630107 ,  0.17095771, -0.0393884 , ..., -0.06473331,
#         -0.03398952,  0.03994337], dtype=float32),
#  array([ 0.010541  ,  0.10453   ,  0.00962439, ..., -0.04857785,
#         -0.11018494,  0.03601863], dtype=float32),
#  array([ 0.06863182,  0.1587208 ,  0.13718899, ..., -0.00106078,
#         -0.07974742,  0.05148577], dtype=float32),
#  array([ 0.10628751,  0.02039354, -0.03091417, ...,  0.02211083,
#         -0.0756387 ,  0.039134  ], dtype=float32),
#  array([ 0.00176298, -0.08880141, -0.12944585, ..., -0.11371739,
#         -0.1514179 ,  0.03451165], dtype=float32),
#  array([ 0.01769454,  0.16739509, -0.05939002, ..., -0.1031353 ,
#         -0.19429916,  0.03557638], dtype=float32),
#  array([ 0.09803455,  0.20580195, -0.00791072, ..., -0.04948717,
#         -0.02587348,  0.0224762 ], dtype=float32),
#  array([ 0.21777993,  0.26269257, -0.05186378, ..., -0.05507809,
#         -0.02197295,  0.13180874], dtype=float32),
#  array([-0.07429759,  0.35492665,  0.07066819, ...,  0.00251289,
#         -0.15516882,  0.04881942], dtype=float32),
#  array([ 0.03202618,  0.2079684 ,  0.12460202, ..., -0.10876045,
#         -0.11544181,  0.20654154], dtype=float32),
#  array([ 0.02547476,  0.22491066,  0.06879419, ..., -0.06372762,
#         -0.02261941, -0.1944475 ], dtype=float32),
#  array([ 0.05186166,  0.06216685,  0.01149169, ..., -0.04132942,
#         -0.02929909,  0.12057693], dtype=float32),
#  array([ 0.19395657,  0.14071305, -0.05281698, ..., -0.11636414,
#         -0.00802921,  0.16282232], dtype=float32),
#  array([-0.00474099,  0.00700096, -0.05456362, ..., -0.02267107,
#         -0.0743176 , -0.05440432], dtype=float32),
#  array([ 0.06680024,  0.15127128, -0.11151935, ..., -0.08370372,
#         -0.04900347,  0.02417845], dtype=float32),
#  array([ 0.02918888,  0.06535727, -0.01843269, ...,  0.02149157,
#          0.10537518,  0.16232452], dtype=float32),
#  array([ 0.22390586,  0.29321858,  0.09305353, ..., -0.11530805,
#         -0.0142423 ,  0.21706712], dtype=float32),
#  array([-0.09532241,  0.02174364, -0.04874918, ...,  0.06183284,
#         -0.00834726,  0.03595611], dtype=float32),
#  array([ 0.01253215,  0.14172633, -0.03344728, ..., -0.01942097,
#         -0.09406199,  0.15364754], dtype=float32),
#  array([ 0.1163796 ,  0.20363039, -0.21926944, ..., -0.1522794 ,
#         -0.21698624,  0.12025774], dtype=float32),
#  array([ 0.03317543,  0.3323518 ,  0.06393546, ..., -0.00820413,
#         -0.1469746 ,  0.0978398 ], dtype=float32),
#  array([ 1.19593926e-01,  2.48426467e-01, -1.30721703e-01, ...,
#          1.80744439e-01, -2.03460848e-04,  8.79999027e-02], dtype=float32),
#  array([-3.8801178e-02,  1.0783199e-01,  1.4886717e-04, ...,
#         -4.3886773e-02, -1.7778677e-01,  1.1786265e-01], dtype=float32),
#  array([ 0.04099418,  0.10472555, -0.12861434, ...,  0.04391415,
#          0.01377933,  0.04485998], dtype=float32),
#  array([ 0.13555332,  0.19797416,  0.03264778, ..., -0.09600822,
#         -0.09922866,  0.07447416], dtype=float32),
#  array([ 3.79833505e-02,  2.08576098e-01,  3.94385308e-03, ...,
#          1.10364474e-01, -1.16744239e-04,  4.83123623e-02], dtype=float32),
#  array([ 0.11944176,  0.16492182,  0.11037611, ..., -0.02458373,
#         -0.15352666, -0.00443193], dtype=float32),
#  array([-0.01191063,  0.16525012, -0.11267189, ...,  0.07512457,
#          0.06403961,  0.06400637], dtype=float32),
#  array([ 0.01952066,  0.20066202,  0.05899649, ..., -0.0696269 ,
#         -0.20167874,  0.00160777], dtype=float32),
#  array([-0.06344059,  0.24228805,  0.12643613, ...,  0.04083363,
#         -0.12603036,  0.08833055], dtype=float32),
#  array([ 0.1708554 , -0.00919717, -0.01852541, ..., -0.00627561,
#         -0.16930267,  0.12377908], dtype=float32),
#  array([-0.03261455,  0.17597973,  0.01268343, ..., -0.00966956,
#         -0.10882594, -0.01278889], dtype=float32),
#  array([ 0.04781267,  0.10787685, -0.09794813, ..., -0.10057332,
#          0.01204825, -0.0016358 ], dtype=float32),
#  array([ 0.00806146, -0.03289999, -0.20545146, ..., -0.00345686,
#         -0.26303592, -0.07409959], dtype=float32),
#  array([0.11303215, 0.18055546, 0.12458844, ..., 0.04764213, 0.10018177,
#         0.09491912], dtype=float32),
#  array([ 0.0429186 ,  0.18200202, -0.07487763, ..., -0.1277307 ,
#         -0.09280062, -0.03773939], dtype=float32),
#  array([-0.0192836 ,  0.1102045 , -0.09593509, ..., -0.07764619,
#         -0.20870936, -0.08714753], dtype=float32),
#  array([ 0.10209513,  0.11372606, -0.0282407 , ...,  0.01429808,
#         -0.01274242,  0.04539428], dtype=float32),
#  array([-0.10650413,  0.1649732 , -0.07131468, ..., -0.09657209,
#          0.10535914,  0.08123135], dtype=float32),
#  array([ 0.04151065,  0.08095852,  0.11986335, ..., -0.03297551,
#         -0.12305897, -0.07933883], dtype=float32),
#  array([ 0.02635649,  0.3154668 , -0.0032955 , ...,  0.01227829,
#         -0.07186008,  0.03002223], dtype=float32),
#  array([ 0.18468466,  0.25662145, -0.04678154, ..., -0.07062092,
#         -0.13663004,  0.1010505 ], dtype=float32),
#  array([ 0.09439871,  0.09220277, -0.02101126, ..., -0.03929587,
#          0.03182715,  0.17314194], dtype=float32),
#  array([ 0.07089961,  0.21304277, -0.00642576, ..., -0.10453756,
#          0.01282224,  0.09659387], dtype=float32),
#  array([ 0.04912157,  0.2676025 , -0.06150337, ..., -0.00366282,
#         -0.11592127,  0.15188308], dtype=float32),
#  array([ 0.12707779,  0.24313653, -0.09394391, ..., -0.0377159 ,
#         -0.00092022,  0.31401438], dtype=float32),
#  array([ 0.07895797,  0.07072879, -0.23644267, ..., -0.07620012,
#         -0.01356325,  0.12463105], dtype=float32),
#  array([ 0.10582562,  0.09888771,  0.15281485, ..., -0.02146056,
#         -0.09349842,  0.18200625], dtype=float32),
#  array([ 0.04711859,  0.29711694, -0.10067295, ..., -0.12976627,
#         -0.13520956,  0.0821279 ], dtype=float32),
#  array([ 0.05729521,  0.14465004, -0.12005719, ..., -0.1182793 ,
#         -0.1137754 ,  0.0191781 ], dtype=float32),
#  array([-0.00073983,  0.21933442,  0.07291298, ..., -0.0873848 ,
#         -0.03961148,  0.11367034], dtype=float32),
#  array([ 0.0235725 ,  0.29353607, -0.01687394, ..., -0.08287334,
#         -0.16478536,  0.07280596], dtype=float32),
#  array([ 0.05477013,  0.42112327, -0.10063279, ..., -0.03647286,
#         -0.03917656,  0.10519566], dtype=float32),
#  array([-0.02821165,  0.19077826,  0.06020467, ...,  0.01164524,
#          0.03408624,  0.00842395], dtype=float32),
#  array([ 0.02930116,  0.24423376, -0.01737354, ...,  0.01007062,
#         -0.15828802, -0.0545946 ], dtype=float32),
#  array([ 0.02141445,  0.02384506, -0.13518044, ..., -0.0470516 ,
#         -0.18420304, -0.18887176], dtype=float32),
#  array([ 0.16850801,  0.12510787,  0.11177775, ..., -0.0294304 ,
#         -0.2213044 ,  0.08340588], dtype=float32),
#  array([ 0.05253382,  0.11888514,  0.0149805 , ..., -0.11879689,
#         -0.04245588, -0.03471298], dtype=float32),
#  array([ 0.07133508, -0.03987687,  0.03804647, ..., -0.00045451,
#         -0.2219705 ,  0.25039038], dtype=float32),
#  array([ 0.02689111,  0.17267433,  0.0153591 , ..., -0.02607005,
#         -0.12077096,  0.09425229], dtype=float32),
#  array([ 0.04048397,  0.13330896, -0.0319995 , ..., -0.16169314,
#         -0.06674029, -0.00437579], dtype=float32),
#  array([-0.05619138,  0.2199638 , -0.01372681, ...,  0.02399064,
#          0.04408696, -0.06290259], dtype=float32),
#  array([ 0.08868989,  0.08295686, -0.18788847, ..., -0.08561596,
#         -0.03715834,  0.0295669 ], dtype=float32),
#  array([-0.05928696,  0.35384938, -0.05409693, ...,  0.02314919,
#         -0.1044137 ,  0.04519453], dtype=float32),
#  array([ 0.02524819,  0.29771706,  0.00031963, ..., -0.07655497,
#         -0.27680367,  0.05844161], dtype=float32),
#  array([ 0.08415077,  0.19100314, -0.0215416 , ..., -0.07478461,
#         -0.11902703,  0.1484419 ], dtype=float32),
#  array([ 0.04301847,  0.30179912,  0.13424227, ..., -0.02044999,
#         -0.09139179,  0.05543505], dtype=float32),
#  array([ 0.27586776,  0.05367651, -0.01035587, ..., -0.01979726,
#         -0.07159182,  0.19010937], dtype=float32),
#  array([ 0.0898974 ,  0.16269365, -0.00674412, ..., -0.03331226,
#         -0.10689202,  0.07255097], dtype=float32),
#  array([ 0.0707296 ,  0.15350954, -0.22570823, ..., -0.12577134,
#         -0.09002884,  0.08352792], dtype=float32),
#  array([ 0.08829445,  0.10431991, -0.10625526, ..., -0.07156497,
#          0.04856326,  0.10331757], dtype=float32),
#  array([ 0.05044452,  0.13547088,  0.09723023, ..., -0.05437452,
#         -0.01127623,  0.01604865], dtype=float32),
#  array([ 0.01547841,  0.33610132,  0.18824603, ..., -0.07367159,
#         -0.1533476 , -0.07234617], dtype=float32),
#  array([ 0.00428766,  0.11497947, -0.11403032, ..., -0.0877096 ,
#         -0.10001267,  0.01927202], dtype=float32),
#  array([-0.04794331,  0.1336899 ,  0.02629794, ..., -0.00479763,
#         -0.04226919,  0.22497801], dtype=float32),
#  array([ 0.12351532,  0.13417633, -0.07484257, ..., -0.00435806,
#          0.03381429,  0.15162499], dtype=float32),
#  array([ 0.15888476,  0.2738957 ,  0.07969266, ..., -0.08803632,
#         -0.07766068,  0.16213523], dtype=float32),
#  array([-0.09717908,  0.24476805,  0.09439405, ..., -0.05272947,
#         -0.09174796,  0.04610271], dtype=float32),
#  array([-0.10557576,  0.22380844, -0.01712438, ..., -0.14380397,
#         -0.06794414,  0.07360829], dtype=float32),
#  array([ 0.10513122,  0.23626207, -0.12561524, ...,  0.20812184,
#         -0.15351126,  0.1136622 ], dtype=float32),
#  array([ 0.02085647,  0.20182066, -0.07383493, ..., -0.12346888,
#         -0.03330432, -0.05568873], dtype=float32),
#  array([ 0.00305462,  0.10545643, -0.10735285, ..., -0.0120864 ,
#          0.02178974,  0.2553193 ], dtype=float32),
#  array([ 0.08156543,  0.27589753,  0.10702975, ..., -0.06171289,
#         -0.0678185 ,  0.14306079], dtype=float32),
#  array([ 0.05119098,  0.12419146,  0.17106768, ..., -0.21326712,
#         -0.0430347 , -0.06663264], dtype=float32),
#  array([-0.0060955 ,  0.24732737,  0.03135706, ...,  0.0934983 ,
#         -0.06318654, -0.02030094], dtype=float32),
#  array([ 0.16729873,  0.02195331,  0.07610248, ..., -0.11690098,
#         -0.19279587,  0.17240837], dtype=float32),
#  array([-0.08186296,  0.20165317,  0.11963271, ..., -0.09319822,
#         -0.1199588 ,  0.06437485], dtype=float32),
#  array([ 0.10116171,  0.16330801, -0.05184319, ...,  0.00038491,
#          0.01879947,  0.11956704], dtype=float32),
#  array([ 0.0519492 ,  0.35096788,  0.1152584 , ..., -0.02560308,
#          0.05886772,  0.18562268], dtype=float32),
#  array([ 0.02284184,  0.1429619 ,  0.13434498, ..., -0.11047053,
#         -0.09373066, -0.00047307], dtype=float32),
#  array([ 0.10914156,  0.1733092 ,  0.04550194, ..., -0.04559093,
#         -0.02206196,  0.10837279], dtype=float32),
#  array([-0.00126274,  0.17510106,  0.0716937 , ..., -0.02382497,
#         -0.08498575,  0.15380418], dtype=float32),
#  array([-0.01028247,  0.26126024,  0.1184267 , ..., -0.06090084,
#          0.06493326,  0.0835813 ], dtype=float32),
#  array([-0.03983762,  0.17915133, -0.06721114, ..., -0.11449509,
#         -0.16315088,  0.02394342], dtype=float32),
#  array([-0.037967  ,  0.23990266,  0.02071495, ..., -0.06504077,
#         -0.21890415,  0.02322441], dtype=float32),
#  array([ 0.23464642,  0.23530142,  0.08773228, ...,  0.05289073,
#         -0.0539464 ,  0.07149351], dtype=float32),
#  array([ 0.00823505,  0.20718727, -0.08497703, ..., -0.04617599,
#         -0.04180485,  0.1633503 ], dtype=float32),
#  array([-0.05960044,  0.3570392 , -0.06551704, ...,  0.1138408 ,
#         -0.02424281,  0.08235852], dtype=float32),
#  array([ 0.1502894 ,  0.31794623,  0.04434563, ...,  0.01572245,
#         -0.11969575, -0.0038631 ], dtype=float32),
#  array([ 0.09978896,  0.0688666 , -0.05809965, ..., -0.03777993,
#         -0.05755544,  0.15795058], dtype=float32),
#  array([0.04384733, 0.19154261, 0.11426985, ..., 0.00194715, 0.10966642,
#         0.14797242], dtype=float32),
#  array([-0.00724907,  0.26168504, -0.0216588 , ..., -0.01989794,
#          0.04900473,  0.047739  ], dtype=float32),
#  array([ 0.0265173 ,  0.08078512, -0.07464081, ..., -0.1211707 ,
#         -0.12051617,  0.06835268], dtype=float32),
#  array([ 0.06209061,  0.14576703,  0.07671682, ...,  0.0338508 ,
#         -0.01289265,  0.01144263], dtype=float32),
#  array([ 0.11519957, -0.05352697, -0.08554238, ..., -0.03666669,
#         -0.01806017,  0.15464032], dtype=float32),
#  array([ 0.14117339,  0.11900315,  0.03970852, ..., -0.06003067,
#          0.02487146,  0.10996006], dtype=float32),
#  array([ 0.00456148,  0.22782283, -0.03382406, ..., -0.06338533,
#         -0.05507173,  0.13222061], dtype=float32),
#  array([ 0.1332409 ,  0.08687524, -0.01073256, ..., -0.03904907,
#         -0.15250662,  0.14082436], dtype=float32),
#  array([ 0.1306216 ,  0.10177857,  0.05452772, ..., -0.01361504,
#         -0.00270458,  0.09765722], dtype=float32),
#  array([ 0.09013984,  0.08072152, -0.10314063, ..., -0.11497287,
#         -0.13308005,  0.18835407], dtype=float32),
#  array([0.05799726, 0.3129416 , 0.10287265, ..., 0.0408629 , 0.14313467,
#         0.03783307], dtype=float32),
#  array([ 0.02069194,  0.15920287,  0.00830474, ...,  0.0829547 ,
#         -0.0684379 , -0.03585352], dtype=float32),
#  array([-0.04473774,  0.05832204, -0.03956931, ...,  0.00563738,
#         -0.10801774,  0.21103898], dtype=float32),
#  array([ 0.0352888 ,  0.14784582,  0.10516473, ...,  0.01407281,
#         -0.0909498 , -0.139625  ], dtype=float32),
#  array([ 0.11260637,  0.17047611, -0.014667  , ..., -0.08053024,
#         -0.07072727,  0.11880323], dtype=float32),
#  array([-0.06634579,  0.12217814, -0.00220062, ..., -0.00952674,
#         -0.20035931,  0.33217743], dtype=float32),
#  array([-0.13647261,  0.33507597, -0.15564156, ..., -0.06802039,
#         -0.13142945,  0.06587724], dtype=float32),
#  array([ 0.10680258,  0.0386463 ,  0.05441239, ..., -0.0423339 ,
#         -0.18552174,  0.17803934], dtype=float32),
#  array([ 0.27941555, -0.00133606, -0.1683396 , ..., -0.03242532,
#         -0.10253727,  0.10867094], dtype=float32),
#  array([ 0.06620325,  0.1900459 ,  0.0111873 , ..., -0.01491875,
#          0.02467779,  0.08380445], dtype=float32),
#  array([ 0.0343154 ,  0.27015755,  0.13752179, ..., -0.08192572,
#         -0.00455205,  0.17079617], dtype=float32),
#  array([ 0.00683532,  0.30925828,  0.01616883, ...,  0.032179  ,
#         -0.00093669, -0.08170521], dtype=float32),
#  array([ 0.05790556,  0.18735982,  0.01550811, ...,  0.0536568 ,
#         -0.23934443,  0.00057073], dtype=float32),
#  array([ 0.10446392,  0.06238692,  0.07127448, ..., -0.07473183,
#         -0.04408309,  0.2430968 ], dtype=float32),
#  array([-0.20456578,  0.14534459,  0.12179786, ...,  0.0622291 ,
#         -0.13043714,  0.08954728], dtype=float32),
#  array([-0.1373835 ,  0.24851996,  0.0839214 , ..., -0.01319586,
#          0.02423585, -0.1465662 ], dtype=float32),
#  array([ 0.02704024,  0.23373592, -0.01933968, ..., -0.06871971,
#         -0.21717244, -0.10301917], dtype=float32),
#  array([ 0.10956261,  0.24696122,  0.1058166 , ..., -0.03431489,
#         -0.1694884 ,  0.01396502], dtype=float32),
#  array([ 0.09206965,  0.24045286,  0.08285399, ..., -0.03056989,
#         -0.08949501,  0.06367088], dtype=float32),
#  array([ 0.10895063,  0.13014062, -0.09875866, ..., -0.10617985,
#         -0.14240296,  0.00898396], dtype=float32),
#  array([ 0.05489899,  0.22416914, -0.14394575, ...,  0.01575624,
#         -0.02949994,  0.08559311], dtype=float32),
#  array([ 0.1458077 ,  0.01141045, -0.12650143, ..., -0.00268531,
#         -0.11280994,  0.0330572 ], dtype=float32),
#  array([ 0.10489661,  0.27297577,  0.07657281, ..., -0.07052742,
#         -0.16709052,  0.23938599], dtype=float32),
#  array([ 0.04088604,  0.18662338, -0.03044447, ...,  0.17808431,
#          0.02167697,  0.2952555 ], dtype=float32),
#  array([-0.03316058,  0.30164066, -0.02928492, ..., -0.0538111 ,
#         -0.1419188 ,  0.06250125], dtype=float32),
#  array([ 0.00741179,  0.15747428, -0.12774211, ...,  0.04128281,
#          0.12690504,  0.12320194], dtype=float32),
#  array([ 0.03076936,  0.29882064, -0.03703411, ..., -0.10842644,
#          0.02179292,  0.0247057 ], dtype=float32),
#  array([ 0.23552918,  0.07330803,  0.04594922, ..., -0.0524544 ,
#         -0.08675799,  0.1363368 ], dtype=float32),
#  array([ 0.0095266 ,  0.13183299, -0.00347048, ...,  0.01287634,
#          0.02719915,  0.1872804 ], dtype=float32),
#  array([ 0.1329403 ,  0.11043273, -0.22165246, ..., -0.05817098,
#         -0.1192606 ,  0.08002526], dtype=float32),
#  array([-0.05884835,  0.01965174,  0.03962677, ...,  0.04081425,
#         -0.00796072, -0.00265473], dtype=float32),
#  array([ 0.06302825,  0.15277608,  0.1686087 , ..., -0.07335544,
#         -0.03765314,  0.15948911], dtype=float32),
#  array([ 0.11608948,  0.30777878,  0.07375797, ..., -0.00701158,
#         -0.06782676,  0.10723689], dtype=float32),
#  array([ 0.1306132 ,  0.13788807, -0.06340516, ..., -0.04493337,
#          0.04740587,  0.12421343], dtype=float32),
#  array([[ 0.07500556,  0.3740229 , -0.02825728, ...,  0.03441251,
#          -0.05378072,  0.15775253],
#         [ 0.03054708,  0.20392932,  0.08075482, ...,  0.02446914,
#          -0.02707948,  0.11904263],
#         [ 0.12761739,  0.02926992,  0.02568356, ..., -0.04536219,
#           0.06777976,  0.26207915],
#         ...,
#         [ 0.14250459,  0.1513087 , -0.03693841, ..., -0.01589542,
#          -0.10272248,  0.2139853 ],
#         [ 0.17351659,  0.104845  ,  0.05538021, ..., -0.08230813,
#          -0.06319945,  0.04628719],
#         [ 0.16748519,  0.3535327 ,  0.1478095 , ...,  0.05012246,
#          -0.09393249, -0.01726118]], dtype=float32),
#  array([ 0.1767992 ,  0.21108817, -0.06886587, ..., -0.05161142,
#         -0.05408948,  0.14472045], dtype=float32),
#  array([-0.06216937, -0.01786601,  0.08054693, ...,  0.05136192,
#         -0.04526832, -0.08699405], dtype=float32),
#  array([ 0.02269527,  0.11346784, -0.08574526, ..., -0.03972256,
#         -0.06998348, -0.06602814], dtype=float32),
#  array([-0.01239993,  0.17889322,  0.15862843, ..., -0.09243347,
#          0.05520405,  0.2288678 ], dtype=float32),
#  array([-0.01930816,  0.07390482,  0.02939428, ..., -0.13906047,
#         -0.01064526,  0.10996444], dtype=float32),
#  array([ 0.02641454,  0.13502134,  0.03535772, ..., -0.12758914,
#         -0.04919235,  0.18324557], dtype=float32),
#  array([-0.16364004,  0.08578869, -0.09707464, ..., -0.08818381,
#         -0.06896596, -0.2306929 ], dtype=float32),
#  array([0.11569358, 0.22234339, 0.02908379, ..., 0.03042709, 0.07990246,
#         0.11068302], dtype=float32),
#  array([-0.09582184,  0.22791792, -0.00182004, ...,  0.00346879,
#         -0.07350783,  0.06474694], dtype=float32),
#  array([-0.10483681,  0.29289067,  0.05588357, ..., -0.12779792,
#         -0.05676817, -0.08786642], dtype=float32),
#  array([ 0.04527783,  0.21767235, -0.04231842, ..., -0.09961201,
#         -0.05089947,  0.15577686], dtype=float32),
#  array([ 0.09704244,  0.08874433, -0.0978464 , ..., -0.06425589,
#         -0.07175625,  0.057155  ], dtype=float32),
#  array([ 0.16894832,  0.10318696,  0.03856737, ...,  0.04604921,
#         -0.06891903,  0.08610673], dtype=float32),
#  array([ 0.04638005,  0.00161253, -0.02192994, ...,  0.01848808,
#         -0.14413701,  0.18169352], dtype=float32),
#  array([ 0.08469106,  0.2391143 ,  0.03706142, ..., -0.03308024,
#          0.00983286,  0.09756374], dtype=float32),
#  array([ 0.00580137,  0.23787498,  0.02576357, ...,  0.08948903,
#         -0.00073251,  0.05669086], dtype=float32),
#  array([ 0.01714416,  0.10312001,  0.00747161, ..., -0.02238257,
#          0.04346693,  0.17378777], dtype=float32),
#  array([-0.02942313,  0.14748825, -0.04600289, ...,  0.04362162,
#         -0.09072149,  0.14634728], dtype=float32),
#  array([ 0.0956956 ,  0.11970692, -0.03607408, ...,  0.01634677,
#          0.05169525,  0.00252504], dtype=float32),
#  array([ 0.14613993,  0.17054427,  0.13035695, ..., -0.02261548,
#         -0.04745435,  0.07128795], dtype=float32),
#  array([-0.0770188 ,  0.2794985 , -0.02348734, ...,  0.05191155,
#          0.00299236,  0.00111444], dtype=float32),
#  array([-0.13289411,  0.14835498,  0.10579752, ..., -0.00481086,
#          0.06421766,  0.2059319 ], dtype=float32),
#  array([-0.07161433, -0.00844596, -0.03872939, ..., -0.03856133,
#         -0.06949235,  0.13876395], dtype=float32),
#  array([ 0.05104134,  0.14375222,  0.04834986, ..., -0.03564284,
#         -0.06813979,  0.11835908], dtype=float32),
#  array([-0.20266853,  0.11342663,  0.1307895 , ...,  0.10245039,
#         -0.11040074,  0.15238635], dtype=float32),
#  array([-0.1145939 ,  0.33209604,  0.10380776, ..., -0.15110378,
#         -0.18764582,  0.02456387], dtype=float32),
#  array([ 0.08229901,  0.22555539, -0.10927792, ..., -0.00695298,
#         -0.20968716,  0.1289272 ], dtype=float32),
#  array([ 0.02756102,  0.16548353, -0.22375949, ..., -0.10485841,
#         -0.21941283, -0.03710118], dtype=float32),
#  array([ 0.13987881, -0.02760296, -0.09881224, ..., -0.1345865 ,
#         -0.09738933,  0.19485083], dtype=float32),
#  array([ 0.00443939,  0.22664282,  0.01726901, ...,  0.03537802,
#         -0.06047332,  0.22027607], dtype=float32),
#  array([ 0.08800965,  0.1406686 , -0.00085234, ..., -0.13439327,
#          0.03106353, -0.09975906], dtype=float32),
#  array([ 0.12354871,  0.18546052,  0.19484842, ..., -0.0648257 ,
#          0.07346439, -0.01101965], dtype=float32),
#  array([-0.03341965,  0.12968524, -0.01611331, ...,  0.00674334,
#         -0.09294213,  0.09737448], dtype=float32),
#  array([ 0.10747239,  0.25326154, -0.04753107, ..., -0.05410779,
#         -0.10028654,  0.03204129], dtype=float32),
#  array([-0.03187741,  0.09749234,  0.07537355, ...,  0.03994723,
#         -0.06597941,  0.06720851], dtype=float32),
#  array([-0.02063861, -0.06699975, -0.11196046, ..., -0.1313341 ,
#         -0.09382989,  0.04057924], dtype=float32),
#  array([-0.09205591,  0.04634275, -0.00429934, ..., -0.09833638,
#         -0.01853667, -0.22494033], dtype=float32),
#  array([ 0.0875685 ,  0.03919614, -0.11256936, ..., -0.02719275,
#          0.02769302,  0.14929762], dtype=float32),
#  array([ 0.12475353,  0.1815031 , -0.00999554, ..., -0.04586012,
#         -0.21830882,  0.04245508], dtype=float32),
#  array([ 0.12079007,  0.18748683, -0.07379398, ..., -0.06134374,
#         -0.00338655,  0.0591842 ], dtype=float32),
#  array([0.06474841, 0.11474559, 0.12260482, ..., 0.04788995, 0.00315591,
#         0.01736664], dtype=float32),
#  array([-0.09389216,  0.22728933,  0.04350049, ...,  0.00543719,
#          0.0236364 ,  0.03716189], dtype=float32),
#  array([ 0.04821097,  0.18285683,  0.14364609, ...,  0.16692476,
#         -0.13434735,  0.17028055], dtype=float32),
#  array([ 0.13672425,  0.07793386,  0.08651336, ...,  0.00058935,
#         -0.17248867,  0.12201793], dtype=float32),
#  array([ 0.09388694,  0.12848398, -0.17982242, ..., -0.00553396,
#          0.01182663, -0.10760131], dtype=float32),
#  array([ 0.05782717,  0.21312657, -0.01848561, ..., -0.01995497,
#         -0.09136972,  0.12420721], dtype=float32),
#  array([ 0.05398593,  0.02760705,  0.01597099, ..., -0.09289456,
#          0.04845793,  0.04004053], dtype=float32),
#  array([ 0.18376604,  0.16515402, -0.12787516, ...,  0.00039248,
#         -0.07354613,  0.13771431], dtype=float32),
#  array([ 0.14257555,  0.04429485, -0.01377816, ..., -0.07894547,
#         -0.16803709, -0.00911719], dtype=float32),
#  array([ 0.01716127,  0.261123  ,  0.18588953, ..., -0.12764335,
#          0.0056231 ,  0.07415501], dtype=float32),
#  array([ 0.12192532, -0.11441232,  0.27282703, ..., -0.09724449,
#         -0.17994498,  0.0582639 ], dtype=float32),
#  array([-0.04089878,  0.30925694, -0.01385353, ..., -0.0672638 ,
#         -0.10650735,  0.08659102], dtype=float32),
#  array([-0.04516124,  0.15644835, -0.02699421, ..., -0.01737782,
#         -0.16403317,  0.05893113], dtype=float32),
#  array([ 0.04892945,  0.23220187,  0.06228784, ..., -0.12446717,
#         -0.11853981,  0.1260639 ], dtype=float32),
#  array([ 0.03349646,  0.15738364, -0.22546268, ..., -0.22679703,
#         -0.31237268,  0.02285506], dtype=float32),
#  array([ 0.09857433,  0.26469713, -0.09231938, ..., -0.04575578,
#         -0.06448299,  0.08924621], dtype=float32),
#  array([ 0.1318511 ,  0.1850356 , -0.00443644, ...,  0.02366955,
#         -0.00970408,  0.18776284], dtype=float32),
#  array([-0.05726891,  0.29198095,  0.15739335, ..., -0.06708413,
#         -0.13162728, -0.11674464], dtype=float32),
#  array([-0.10548634,  0.26915783, -0.11237572, ...,  0.05528289,
#         -0.15872537, -0.00670955], dtype=float32),
#  array([0.02883953, 0.2342031 , 0.10528551, ..., 0.02803877, 0.02021813,
#         0.15363657], dtype=float32),
#  array([ 0.20590004,  0.04742943,  0.01065439, ..., -0.10231742,
#         -0.14815427,  0.06428152], dtype=float32),
#  array([-0.05899675,  0.10498868,  0.30975097, ...,  0.12168626,
#         -0.09344665,  0.21853179], dtype=float32),
#  array([ 0.13912721,  0.28129184, -0.12226257, ..., -0.04063522,
#         -0.00138564,  0.01301727], dtype=float32),
#  array([ 0.06810238,  0.1727906 , -0.04641466, ..., -0.17491265,
#         -0.11660904,  0.02516926], dtype=float32),
#  array([ 0.12191406,  0.20885666,  0.00376778, ...,  0.00460633,
#         -0.22526503,  0.07783424], dtype=float32),
#  array([-0.03437502,  0.19925128,  0.02897605, ...,  0.03952603,
#         -0.23057294,  0.08103933], dtype=float32),
#  array([-0.02099934,  0.12240277, -0.05948729, ...,  0.06550429,
#         -0.08357426,  0.12840092], dtype=float32),
#  array([ 0.0660479 ,  0.19685492, -0.01570847, ..., -0.16487393,
#         -0.159107  ,  0.01581247], dtype=float32),
#  array([0.04245857, 0.04299593, 0.2052155 , ..., 0.06318106, 0.04818266,
#         0.10886026], dtype=float32),
#  array([-0.0631556 ,  0.41238847,  0.07857165, ..., -0.11926062,
#         -0.27834857, -0.0075536 ], dtype=float32),
#  array([ 0.13771246,  0.19112791, -0.05810843, ...,  0.05440074,
#          0.134448  ,  0.09527622], dtype=float32),
#  array([-0.06542575,  0.32094392,  0.01358279, ...,  0.06174662,
#         -0.13456494,  0.13452198], dtype=float32),
#  array([ 0.04412317,  0.09811639,  0.11167648, ..., -0.09698156,
#         -0.06412698,  0.1801705 ], dtype=float32),
#  array([-1.1641062e-01,  3.1990561e-01, -1.4858383e-04, ...,
#         -1.9805746e-02, -2.4940612e-02, -6.9347516e-02], dtype=float32),
#  array([ 0.04843269,  0.16177787, -0.2581638 , ..., -0.02773885,
#         -0.20221204,  0.03295111], dtype=float32),
#  array([ 0.0016682 ,  0.1996598 , -0.05552906, ..., -0.07755274,
#         -0.05158405,  0.1827419 ], dtype=float32),
#  array([ 0.08945616,  0.15907715, -0.04482002, ...,  0.02597893,
#          0.02030427,  0.21950853], dtype=float32),
#  array([-0.23033652,  0.17367443,  0.0231641 , ..., -0.17761277,
#         -0.18207967,  0.01135023], dtype=float32),
#  array([ 0.04956906,  0.10466448,  0.06822814, ..., -0.10123698,
#         -0.07817763,  0.12718056], dtype=float32),
#  array([-0.03724848,  0.1765896 ,  0.08362032, ..., -0.05365876,
#          0.02663333,  0.01315644], dtype=float32),
#  array([-0.05489343,  0.22158132, -0.05890613, ..., -0.05863388,
#         -0.06518754,  0.14554556], dtype=float32),
#  array([0.07420753, 0.18245994, 0.12961158, ..., 0.04871552, 0.12686518,
#         0.12892225], dtype=float32),
#  array([ 0.14442435,  0.0977707 ,  0.04445887, ..., -0.00018408,
#         -0.00358156, -0.04027226], dtype=float32),
#  array([ 0.13755469,  0.23683421,  0.027203  , ..., -0.15979163,
#         -0.04867117,  0.07857538], dtype=float32),
#  array([ 0.04573108,  0.19435652,  0.00971123, ..., -0.03625222,
#         -0.21231239,  0.20376125], dtype=float32),
#  array([-0.0031643 ,  0.22033879,  0.03473514, ..., -0.01250295,
#         -0.08480751,  0.09292713], dtype=float32),
#  array([-0.02945215,  0.27268052,  0.2391292 , ...,  0.04454783,
#         -0.02743125,  0.1624962 ], dtype=float32),
#  array([-0.03534634,  0.28901297,  0.01687245, ..., -0.04920339,
#         -0.28141525,  0.08593988], dtype=float32),
#  array([ 0.11556751,  0.22118938, -0.13232498, ..., -0.12058273,
#         -0.15805896,  0.0359142 ], dtype=float32),
#  array([ 0.01247492,  0.36991927, -0.16495138, ..., -0.07623848,
#         -0.095535  ,  0.03572315], dtype=float32),
#  array([-0.16379431,  0.31571993, -0.09962621, ...,  0.04786172,
#         -0.18494782, -0.03951368], dtype=float32),
#  array([ 0.05539792,  0.20525756,  0.18147387, ...,  0.12434477,
#         -0.11387506,  0.19932047], dtype=float32),
#  array([-0.02198933,  0.24169715,  0.18547063, ...,  0.03699107,
#          0.0798974 ,  0.22212175], dtype=float32),
#  array([ 0.06142685,  0.09136066, -0.01658406, ..., -0.06332155,
#         -0.07498373, -0.11523998], dtype=float32),
#  array([-0.02989238,  0.24285164, -0.07870613, ..., -0.04896573,
#         -0.07996739,  0.12727001], dtype=float32),
#  array([ 0.04310837,  0.29146433,  0.17339526, ..., -0.03200455,
#         -0.07998165,  0.14238594], dtype=float32),
#  array([-0.05049114,  0.36243343, -0.0083791 , ..., -0.05486138,
#         -0.10497406, -0.03331919], dtype=float32),
#  array([ 0.00152101,  0.09837137,  0.03452641, ..., -0.14203352,
#         -0.10104328,  0.01138615], dtype=float32),
#  array([ 0.09635219,  0.22310458, -0.09503707, ..., -0.09763525,
#         -0.01932115,  0.03585138], dtype=float32),
#  array([-0.10446437,  0.13099593,  0.04411242, ..., -0.03869459,
#         -0.14878674,  0.05532988], dtype=float32),
#  array([ 0.14618003, -0.05191433, -0.2264    , ...,  0.10525751,
#         -0.11927795, -0.05783153], dtype=float32),
#  array([-0.00470273,  0.33538824,  0.14361854, ..., -0.05453773,
#         -0.09318627,  0.13869637], dtype=float32),
#  array([-0.05429974,  0.31482673, -0.02496696, ..., -0.02009276,
#         -0.14329055,  0.13839547], dtype=float32),
#  array([ 0.20552173,  0.05831907,  0.05444299, ..., -0.15072244,
#         -0.25252488,  0.1852698 ], dtype=float32),
# ...
#          0.08348048,  0.11269135], dtype=float32),
#  array([ 0.11695946,  0.28664282, -0.09247219, ..., -0.06118403,
#         -0.19014215,  0.02553915], dtype=float32),
#  array([ 0.02468767,  0.22986348, -0.01275658, ...,  0.08745497,
#         -0.02795965, -0.0679064 ], dtype=float32),
#  array([ 0.08982112,  0.01928987, -0.07150993, ..., -0.15229008,
#         -0.25815016, -0.03030423], dtype=float32),
#  array([ 0.07420903,  0.09054832, -0.21488315, ..., -0.06629921,
#         -0.0304955 ,  0.04022148], dtype=float32),
#  array([ 0.00567382,  0.10503903, -0.1363618 , ..., -0.02797793,
#         -0.02640963,  0.08892072], dtype=float32),
#  array([ 0.01164817,  0.14942546, -0.03698857, ..., -0.02141706,
#         -0.12441968,  0.20670135], dtype=float32),
#  array([ 0.14245401,  0.0724699 ,  0.16261873, ..., -0.02299713,
#          0.05688222,  0.09884796], dtype=float32),
#  array([ 0.17443754,  0.15686125,  0.13821426, ..., -0.07677477,
#          0.02451374,  0.21614774], dtype=float32),
#  array([ 0.10328784,  0.2321644 ,  0.01511586, ..., -0.05549423,
#         -0.1020933 ,  0.09917887], dtype=float32),
#  array([ 0.142648  ,  0.34463158,  0.2322463 , ..., -0.14968134,
#         -0.13047366, -0.14237358], dtype=float32),
#  array([-0.10536817,  0.09488363,  0.1125738 , ..., -0.01846784,
#         -0.0650988 ,  0.18794356], dtype=float32),
#  array([ 0.01077069,  0.28845263, -0.04588473, ..., -0.16270001,
#         -0.19157717,  0.10930118], dtype=float32),
#  array([ 1.17361285e-01,  2.44970992e-01,  6.33354139e-05, ...,
#         -2.96509620e-02, -8.38345289e-02,  1.51891872e-01], dtype=float32),
#  array([ 0.09828115,  0.09045961, -0.05100001, ..., -0.00291851,
#         -0.02380877,  0.13418931], dtype=float32),
#  array([ 0.01270313,  0.08942882,  0.04717148, ...,  0.06980091,
#         -0.09229005,  0.09521975], dtype=float32),
#  array([ 0.06822716,  0.29378718, -0.05411054, ..., -0.08204227,
#         -0.03894401,  0.09473287], dtype=float32),
#  array([-0.04784185,  0.17213942, -0.0932488 , ...,  0.11731961,
#          0.11897206,  0.10629945], dtype=float32),
#  array([ 0.02891611,  0.16830826, -0.02028235, ...,  0.04508225,
#         -0.06898759,  0.0442435 ], dtype=float32),
#  array([ 0.00806593,  0.3160911 ,  0.14326362, ..., -0.0765254 ,
#         -0.08888815, -0.07397716], dtype=float32),
#  array([0.07048528, 0.21980359, 0.05347024, ..., 0.01481514, 0.00359767,
#         0.32306248], dtype=float32),
#  array([ 0.03987458,  0.2016059 ,  0.04592462, ..., -0.04967383,
#         -0.053795  ,  0.12935567], dtype=float32),
#  array([ 0.04334017,  0.23989455,  0.04368952, ..., -0.09309357,
#         -0.09938933,  0.13992761], dtype=float32),
#  array([-0.02201777,  0.03605514, -0.16338566, ..., -0.20958653,
#         -0.15475966, -0.04310351], dtype=float32),
#  array([-0.0105475 ,  0.13185064,  0.05575157, ..., -0.18190074,
#         -0.1229463 ,  0.02963947], dtype=float32),
#  array([ 0.08742883,  0.06999223, -0.05603945, ..., -0.06271236,
#         -0.06928002,  0.07818975], dtype=float32),
#  array([ 0.15209676,  0.24836949, -0.10049351, ...,  0.02580355,
#         -0.11701421,  0.16145696], dtype=float32),
#  array([-0.23446555,  0.15695576,  0.16958524, ..., -0.13292281,
#         -0.1367845 , -0.09136245], dtype=float32),
#  array([ 0.0450801 ,  0.18455987,  0.16422899, ..., -0.01310533,
#         -0.03211607,  0.06619017], dtype=float32),
#  array([ 0.1015834 ,  0.02332712, -0.06318761, ...,  0.06432759,
#         -0.07786659,  0.20258747], dtype=float32),
#  array([ 0.03766273,  0.16558231, -0.08499351, ..., -0.03254712,
#         -0.10522136,  0.13714495], dtype=float32),
#  array([ 0.04638122,  0.14059313, -0.07833432, ...,  0.04133933,
#         -0.10718928,  0.04151917], dtype=float32),
#  array([ 0.1222422 ,  0.2287348 ,  0.09437227, ..., -0.01787931,
#         -0.03226657,  0.18085533], dtype=float32),
#  array([ 0.06178845,  0.07481153, -0.051764  , ..., -0.28620866,
#         -0.09624147, -0.10195827], dtype=float32),
#  array([ 0.03907415,  0.19418891,  0.05872211, ..., -0.16098149,
#         -0.13577242,  0.24201144], dtype=float32),
#  array([0.16881208, 0.03749762, 0.0056911 , ..., 0.04510432, 0.09180009,
#         0.11414529], dtype=float32),
#  array([ 0.06076276,  0.30879498,  0.08761138, ..., -0.04117032,
#         -0.06243973,  0.12756081], dtype=float32),
#  array([ 0.09524684,  0.12791981,  0.01642405, ..., -0.08630438,
#          0.0508388 , -0.02331541], dtype=float32),
#  array([ 0.00859767,  0.24085164,  0.04188021, ..., -0.18002613,
#         -0.07062996,  0.06031121], dtype=float32),
#  array([ 0.14659141,  0.12983996, -0.05361741, ..., -0.02216542,
#          0.05062323,  0.02546855], dtype=float32),
#  array([ 0.16593549,  0.27515823,  0.11358196, ..., -0.07974751,
#         -0.13243446,  0.21121106], dtype=float32),
#  array([ 0.07827036,  0.18910788, -0.16376486, ...,  0.07479057,
#         -0.06483646,  0.07275984], dtype=float32),
#  array([ 0.08855633,  0.08138426,  0.06758697, ..., -0.01768219,
#          0.03319156,  0.05719748], dtype=float32),
#  array([ 0.07965376,  0.2153078 ,  0.13866773, ..., -0.0372632 ,
#         -0.03650384,  0.08238029], dtype=float32),
#  array([ 0.0060988 ,  0.20294465,  0.06423793, ..., -0.17952673,
#          0.00666499,  0.04544688], dtype=float32),
#  array([ 0.05245315,  0.1586931 ,  0.04315734, ..., -0.11957429,
#         -0.0348052 ,  0.14900935], dtype=float32),
#  array([ 0.14210837,  0.01082882, -0.17365015, ...,  0.00444949,
#         -0.07410603,  0.29089305], dtype=float32),
#  array([-0.02785389,  0.27653357, -0.05777581, ..., -0.03540603,
#         -0.06287962,  0.0369115 ], dtype=float32),
#  array([-0.08348529,  0.26513204, -0.02062776, ..., -0.10298431,
#         -0.13240108,  0.02157647], dtype=float32),
#  array([-0.15081313,  0.22751155,  0.02590802, ..., -0.08084729,
#         -0.08734479,  0.14587468], dtype=float32),
#  array([ 0.10705895,  0.0435922 , -0.03827335, ...,  0.00640427,
#         -0.03525919,  0.0189415 ], dtype=float32),
#  array([-0.00407751,  0.36099422, -0.00579152, ..., -0.08173254,
#          0.01262951, -0.01067999], dtype=float32),
#  array([ 0.05409255,  0.18426412,  0.06724215, ..., -0.05493421,
#         -0.16468102, -0.02576813], dtype=float32),
#  array([ 0.04847859,  0.12212345,  0.04262096, ..., -0.06561694,
#         -0.10431894,  0.05782428], dtype=float32),
#  array([ 0.12422905,  0.17083684,  0.18060133, ..., -0.00895216,
#         -0.13211639, -0.00594866], dtype=float32),
#  array([ 0.06691588,  0.38452008,  0.09193385, ..., -0.06388576,
#          0.01039432,  0.29635063], dtype=float32),
#  array([ 0.10669388,  0.02314769, -0.06947616, ..., -0.0201425 ,
#          0.01842592,  0.01181093], dtype=float32),
#  array([ 0.07912137,  0.12834665, -0.09168775, ...,  0.02799819,
#         -0.04972977, -0.03352448], dtype=float32),
#  array([-0.07727888,  0.11014135,  0.01770519, ..., -0.05504222,
#         -0.05861782,  0.07115734], dtype=float32),
#  array([ 0.09205472,  0.19278842,  0.09588363, ..., -0.02883551,
#         -0.02416515,  0.09709468], dtype=float32),
#  array([ 0.06758335,  0.18598902, -0.12143306, ..., -0.08524615,
#         -0.14221057,  0.15119053], dtype=float32),
#  array([ 0.13116002,  0.10892569,  0.00720026, ..., -0.05410698,
#         -0.06252324, -0.01325337], dtype=float32),
#  array([ 0.0776216 , -0.01169948, -0.06952381, ..., -0.07291317,
#         -0.06469511, -0.03046896], dtype=float32),
#  array([-0.01411321,  0.15822393, -0.12482455, ..., -0.09218229,
#         -0.10994434,  0.10305883], dtype=float32),
#  array([ 0.11789756,  0.23666233, -0.02752226, ...,  0.02887961,
#         -0.11778348,  0.04517654], dtype=float32),
#  array([ 0.07899829,  0.26240534, -0.11940232, ...,  0.12205457,
#         -0.04160666,  0.13215074], dtype=float32),
#  array([ 0.02418375,  0.43612885,  0.14115176, ..., -0.03087046,
#         -0.29169643,  0.06125602], dtype=float32),
#  array([ 0.00926081,  0.26965818, -0.03723015, ..., -0.01751918,
#         -0.10700618,  0.00787378], dtype=float32),
#  array([ 0.04319403,  0.21264793, -0.19757864, ...,  0.0437904 ,
#         -0.13529669,  0.07703588], dtype=float32),
#  array([-0.06432351,  0.19258362,  0.06485669, ..., -0.08908707,
#         -0.15370992, -0.08038605], dtype=float32),
#  array([ 0.00501772,  0.3416792 ,  0.15085387, ..., -0.06769667,
#         -0.13416877, -0.11546675], dtype=float32),
#  array([ 0.04735042,  0.26367158,  0.044088  , ..., -0.01296279,
#         -0.0274969 ,  0.1004041 ], dtype=float32),
#  array([ 0.15103927,  0.19948874, -0.06135215, ..., -0.04765051,
#         -0.06015294,  0.14881702], dtype=float32),
#  array([ 0.08547933,  0.00314175, -0.07350318, ..., -0.08651414,
#         -0.0425048 ,  0.1636343 ], dtype=float32),
#  array([ 0.11770467,  0.10127454, -0.21258917, ..., -0.06940563,
#         -0.11821045, -0.01720762], dtype=float32),
#  array([0.13546874, 0.1975528 , 0.20940512, ..., 0.07241662, 0.07088573,
#         0.17908931], dtype=float32),
#  array([0.0595408 , 0.1401382 , 0.14439954, ..., 0.07600508, 0.09083378,
#         0.06665193], dtype=float32),
#  array([ 0.10151344,  0.21627508, -0.07245132, ..., -0.06052189,
#         -0.01576911, -0.16522951], dtype=float32),
#  array([-0.08789229,  0.15808856,  0.10829473, ...,  0.02543389,
#         -0.03753144,  0.13250105], dtype=float32),
#  array([ 0.20878343,  0.11368135,  0.0826667 , ...,  0.08380891,
#         -0.17184442,  0.15782474], dtype=float32),
#  array([ 0.12194873,  0.08503125, -0.1621903 , ..., -0.09098466,
#         -0.04741334,  0.10029607], dtype=float32),
#  array([ 0.01610572,  0.26062843, -0.09947419, ...,  0.09047939,
#         -0.05559393,  0.27308714], dtype=float32),
#  array([ 0.10973102,  0.1715901 ,  0.05418402, ..., -0.02798512,
#          0.00740738,  0.06856973], dtype=float32),
#  array([ 0.04473053,  0.00896083, -0.00165145, ...,  0.01074939,
#         -0.10153355,  0.16155617], dtype=float32),
#  array([ 0.04870226,  0.22915436,  0.14712234, ..., -0.07350259,
#         -0.11213773,  0.17745565], dtype=float32),
#  array([ 0.01283645,  0.1390212 , -0.05258834, ..., -0.11107272,
#         -0.11486357,  0.09112391], dtype=float32),
#  array([ 0.11518556,  0.19067635,  0.01182273, ...,  0.02905192,
#         -0.16595484,  0.00052649], dtype=float32),
#  array([ 0.1345296 ,  0.05814715,  0.06311227, ..., -0.14168519,
#          0.05557012,  0.0438075 ], dtype=float32),
#  array([ 0.01503805,  0.05298268, -0.26116827, ..., -0.05569757,
#         -0.10838685, -0.02606419], dtype=float32),
#  array([ 0.1223291 ,  0.24198556,  0.22983123, ..., -0.17327057,
#         -0.05190908,  0.04761833], dtype=float32),
#  array([ 0.14878705,  0.01731735,  0.00715778, ..., -0.10703999,
#         -0.00199431,  0.0872968 ], dtype=float32),
#  array([-0.12319469,  0.28155628, -0.06001016, ..., -0.03580137,
#          0.0474824 ,  0.14178465], dtype=float32),
#  array([0.11636537, 0.07241531, 0.10778754, ..., 0.1159476 , 0.07483943,
#         0.07097298], dtype=float32),
#  array([ 0.20058767,  0.09533017,  0.07804832, ..., -0.11282277,
#          0.00190365,  0.0406848 ], dtype=float32),
#  array([-0.00938558,  0.15583548, -0.20912555, ..., -0.01985233,
#         -0.09451856,  0.2137539 ], dtype=float32),
#  array([ 0.18919879,  0.1644941 , -0.21517582, ..., -0.06098024,
#         -0.3660791 ,  0.07812475], dtype=float32),
#  array([ 0.000609  ,  0.192981  ,  0.09964619, ..., -0.15485981,
#          0.05184885,  0.18972711], dtype=float32),
#  array([-0.01536577,  0.06459936, -0.02944501, ..., -0.08058805,
#         -0.1816709 , -0.0107503 ], dtype=float32),
#  array([ 0.03802541,  0.16469176, -0.0619441 , ..., -0.04421836,
#         -0.17000292,  0.17342462], dtype=float32),
#  array([-0.08413246,  0.12020229, -0.02802495, ..., -0.01178269,
#         -0.13968186,  0.06229091], dtype=float32),
#  array([ 0.07915822,  0.2797161 ,  0.0606053 , ...,  0.13135438,
#         -0.12970297,  0.20626079], dtype=float32),
#  array([-0.05327309,  0.12734616, -0.09278931, ...,  0.04434586,
#          0.01193731,  0.02164319], dtype=float32),
#  array([ 0.05462319,  0.16899371, -0.13143222, ..., -0.03407689,
#         -0.03628561,  0.1408624 ], dtype=float32),
#  array([ 0.21214992,  0.14492132, -0.09240793, ...,  0.07002574,
#         -0.06323466,  0.25143027], dtype=float32),
#  array([ 0.01832558,  0.09352811, -0.11945867, ..., -0.07395498,
#         -0.13007385,  0.05545228], dtype=float32),
#  array([ 0.08387227,  0.11776806,  0.09837374, ..., -0.01130118,
#         -0.049496  ,  0.02271825], dtype=float32),
#  array([ 0.06239632,  0.2132043 , -0.05130712, ..., -0.00078576,
#         -0.05952346,  0.01206554], dtype=float32),
#  array([ 0.0379691 ,  0.27448675, -0.12384529, ..., -0.10368363,
#         -0.16572331,  0.18078086], dtype=float32),
#  array([ 0.04495171,  0.15341276,  0.06339119, ..., -0.00395264,
#         -0.18257135,  0.26470616], dtype=float32),
#  array([ 0.08983456,  0.17503437,  0.01436031, ...,  0.01797064,
#         -0.07547729,  0.15783651], dtype=float32),
#  array([ 0.05884522,  0.17007971,  0.1038711 , ..., -0.04961123,
#          0.11498918,  0.18567668], dtype=float32),
#  array([-0.02572809,  0.14249101,  0.04937218, ...,  0.01401705,
#         -0.03250667,  0.02354863], dtype=float32),
#  array([ 0.07809334,  0.06160994, -0.00615713, ...,  0.06280877,
#         -0.03696223,  0.12752008], dtype=float32),
#  array([ 0.11839116,  0.02886097, -0.00933782, ..., -0.02651986,
#         -0.12228512,  0.13163827], dtype=float32),
#  array([ 0.04420689,  0.16411985,  0.0836685 , ..., -0.02391804,
#         -0.06261551,  0.02656166], dtype=float32),
#  array([-0.03161429,  0.08357012, -0.14002268, ..., -0.03401053,
#         -0.02287645,  0.05141066], dtype=float32),
#  array([ 0.03995057,  0.11975295,  0.07151134, ...,  0.00815926,
#         -0.03640692,  0.09621059], dtype=float32),
#  array([-0.07763281,  0.21859989, -0.00766315, ...,  0.02153777,
#         -0.19615676, -0.01701307], dtype=float32),
#  array([-0.05410849,  0.16439535,  0.04103453, ...,  0.0216418 ,
#          0.08373163,  0.11162393], dtype=float32),
#  array([ 0.05313258,  0.10702036, -0.04652103, ..., -0.03917088,
#         -0.09111281,  0.05432656], dtype=float32),
#  array([ 0.07804818,  0.09112928, -0.03446239, ..., -0.09200684,
#         -0.05239406, -0.05094279], dtype=float32),
#  array([-0.02299838,  0.1522411 , -0.05719278, ..., -0.00942741,
#         -0.21593389,  0.12702997], dtype=float32),
#  array([ 0.00804814,  0.14908944, -0.03001534, ..., -0.09596909,
#          0.021859  ,  0.06900673], dtype=float32),
#  array([ 0.05013408,  0.16829425, -0.10181949, ...,  0.00572031,
#         -0.07745963,  0.35509107], dtype=float32),
#  array([-0.09657969,  0.30067402, -0.02532351, ..., -0.10757181,
#         -0.03219875, -0.07016163], dtype=float32),
#  array([ 0.13015969,  0.10020909,  0.05377249, ..., -0.0130773 ,
#          0.05735211,  0.15721971], dtype=float32),
#  array([ 0.16275337, -0.02995415, -0.10686269, ..., -0.01407713,
#          0.14174388,  0.17489691], dtype=float32),
#  array([ 0.0614137 ,  0.37271667,  0.01936969, ..., -0.03949367,
#         -0.04306595,  0.29478922], dtype=float32),
#  array([ 0.10989818,  0.25112957,  0.02773636, ...,  0.02694583,
#         -0.14540811,  0.0327289 ], dtype=float32),
#  array([-0.14067839,  0.19240256,  0.1591837 , ..., -0.1476286 ,
#          0.03280741, -0.14607316], dtype=float32),
#  array([-0.09641821,  0.30739334,  0.11575766, ...,  0.17468873,
#         -0.17037676,  0.17830901], dtype=float32),
#  array([-0.00908449,  0.23936895,  0.07054929, ..., -0.03542503,
#         -0.15256244, -0.0362443 ], dtype=float32),
#  array([ 0.04253266,  0.09801164,  0.00366126, ..., -0.07296147,
#         -0.01722876,  0.15447858], dtype=float32),
#  array([ 0.12573275,  0.3230998 , -0.125441  , ..., -0.07404552,
#         -0.02567548,  0.05305443], dtype=float32),
#  array([ 0.08521605,  0.06859022,  0.02932649, ...,  0.04695322,
#         -0.263958  ,  0.16453439], dtype=float32),
#  array([ 0.06296319,  0.14084533, -0.00285297, ..., -0.04434923,
#          0.00930123,  0.07398867], dtype=float32),
#  array([-0.00587821,  0.15443443, -0.08906723, ..., -0.0484718 ,
#         -0.13550615, -0.00598944], dtype=float32),
#  array([-0.02542685,  0.27066898, -0.05344387, ...,  0.02219963,
#         -0.0296073 ,  0.21035121], dtype=float32),
#  ...]

# %%
train, test = train_test_split(ne_e_test_data, test_size=0.2)

# %%
x_e_train = train['embeddings']
x_e_test = test['embeddings']

# %%
y_e_train = train["enzyme_nonenzyme"]
y_e_test = test["enzyme_nonenzyme"]

# %%
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(x_e_train, y_e_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-185-5084118166f7> in <module>
#       1 neigh = KNeighborsClassifier(n_neighbors=5)
# ----> 2 neigh.fit(x_e_train, y_e_train)
#
# /usr/local/lib/python3.9/site-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     177             The fitted k-nearest neighbors classifier.
#     178         """
# --> 179         return self._fit(X, y)
#     180
#     181     def predict(self, X):
#
# /usr/local/lib/python3.9/site-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     361         if self._get_tags()["requires_y"]:
#     362             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 363                 X, y = self._validate_data(X, y, accept_sparse="csr",
#     364                                            multi_output=True)
#     365
#
# /usr/local/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# /usr/local/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# /usr/local/lib/python3.9/site-packages/pandas/core/series.py in __array__(self, dtype)
#     766               dtype='datetime64[ns]')
#     767         """
# --> 768         return np.asarray(self.array, dtype)
#     769
#     770     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# /usr/local/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py in __array__(self, dtype)
#     201
#     202     def __array__(self, dtype=None) -> np.ndarray:
# --> 203         return np.asarray(self._ndarray, dtype=dtype)
#     204
#     205     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# /usr/local/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# #### Class Classification

# %%
infile = open("./gb_enzyme_class_esm.pkl",'rb')

# %%
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator GaussianNB from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test_class, y_pred)
# Out:
# 0.3527777777777778

# %% [markdown]
# #### Enzyme Non Enzyme Classification

# %%
infile = open("./gb_enzyme_non_enzyme_esm.pkl",'rb')

# %%
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator GaussianNB from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_binary_test)
# Out:
# /usr/local/lib/python3.9/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-3ca8084dd4f0> in <module>
# ----> 1 y_pred = model.predict(x_binary_test)
#
# /usr/local/lib/python3.9/site-packages/sklearn/naive_bayes.py in predict(self, X)
#      72         """
#      73         check_is_fitted(self)
# ---> 74         X = self._check_X(X)
#      75         jll = self._joint_log_likelihood(X)
#      76         return self.classes_[np.argmax(jll, axis=1)]
#
# /usr/local/lib/python3.9/site-packages/sklearn/naive_bayes.py in _check_X(self, X)
#     211
#     212     def _check_X(self, X):
# --> 213         return check_array(X)
#     214
#     215     @staticmethod
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     692             # If input is 1D raise error
#     693             if array.ndim == 1:
# --> 694                 raise ValueError(
#     695                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[array([ 0.12746994,  0.27281544,  0.06692323, ...,  0.03192677,
#         -0.12083121,  0.10100751], dtype=float32)
#  array([ 0.12582903,  0.11324516,  0.11739114, ..., -0.10598259,
#         -0.09380031,  0.09344083], dtype=float32)
#  array([ 0.13101612,  0.30415857,  0.17695493, ..., -0.1529716 ,
#         -0.10064235,  0.05371748], dtype=float32)                ...
#  array([-0.07030933,  0.01263661, -0.0583692 , ..., -0.08494956,
#          0.01382006,  0.01726289], dtype=float32)
#  array([ 0.12393214,  0.13972586,  0.03937945, ...,  0.01177074,
#         -0.0671177 , -0.04921646], dtype=float32)
#  array([ 0.07451792,  0.0815477 , -0.00480333, ..., -0.03443815,
#         -0.07907216,  0.0944355 ], dtype=float32)               ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
accuracy_score(y_test_binary, y_pred)
# Out:
# 0.25833333333333336

# %% [markdown]
# ###  Random Forest

# %% [markdown]
# #### Class Classification

# %%
infile = open("./rf_enzyme_class_esm.pkl",'rb')
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test_class, y_pred)
# Out:
# 0.4361111111111111

# %% [markdown]
# #### Enzyme Non Enzyme Classification

# %%
infile = open("./rf_enzyme_non_enzyme_esm.pkl",'rb')
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test_binary, y_pred)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:208: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# 0.0

# %% [markdown]
# ### KNN

# %% [markdown]
# #### Class Classification

# %%
infile = open("./knn_enzyme_class_esm.pkl",'rb')
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator KNeighborsClassifier from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test_class, y_pred)
# Out:
# 0.5333333333333333

# %% [markdown]
# #### Enzyme Non Enzyme Classification

# %%
infile = open("./knn_enzyme_non_enzyme_esm.pkl",'rb')
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator KNeighborsClassifier from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test_binary, y_pred)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:208: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# 0.0

# %% [markdown]
# ### MLP

# %% [markdown]
# #### Class Classification

# %%
infile = open("./mlp_enzyme_class_esm.pkl",'rb')
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test_class, y_pred)
# Out:
# 0.6388888888888888

# %% [markdown]
# #### Enzyme Non Enzyme Classification

# %%
infile = open("./mlp_enzyme_non_enzyme_esm.pkl",'rb')
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test_binary, y_pred)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:208: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# 0.0

# %% [markdown]
# ### SVC

# %% [markdown]
# #### Class Classification

# %% [markdown]
# #### Enzyme Non Enzyme Classification

# %%
infile = open("./svc_enzyme_non_enzyme_esm.pkl",'rb')
model = pickle.load(infile)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator SVC from version 0.23.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test_binary, y_pred)
